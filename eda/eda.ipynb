# %% [markdown]
# # Exploratory Data Analysis
#
# This is a exploratory data analysis of the cars.csv dataset. The goal is to convert data from the initial format to a format that may be better for analysis. Please note that all code is my own unless otherwise specified.

# %%
import pandas as pd

# %% [markdown]
# Read data from csv, specifying header as first row.

# %%
df = pd.read_csv("cars.csv", header=0)

# %% [markdown]
# Use head to view first five rows of the data.

# %%
df.head()
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 4                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# 1                       True                                           6
# 2                       True                                           6
# 3                       True                                           6
# 4                       True                                           6
#
#   Engine Information.Transmission  Fuel Information.City mpg  \
# 0  6 Speed Automatic Select Shift                         18
# 1  6 Speed Automatic Select Shift                         22
# 2                  6 Speed Manual                         21
# 3  6 Speed Automatic Select Shift                         21
# 4  6 Speed Automatic Select Shift                         21
#
#   Fuel Information.Fuel Type  Fuel Information.Highway mpg  \
# 0                   Gasoline                            25
# 1                   Gasoline                            28
# 2                   Gasoline                            30
# 3                   Gasoline                            28
# 4                   Gasoline                            28
#
#   Identification.Classification           Identification.ID  \
# 0        Automatic transmission            2009 Audi A3 3.2
# 1        Automatic transmission       2009 Audi A3 2.0 T AT
# 2           Manual transmission          2009 Audi A3 2.0 T
# 3        Automatic transmission  2009 Audi A3 2.0 T Quattro
# 4        Automatic transmission  2009 Audi A3 2.0 T Quattro
#
#   Identification.Make Identification.Model Year  Identification.Year  \
# 0                Audi              2009 Audi A3                 2009
# 1                Audi              2009 Audi A3                 2009
# 2                Audi              2009 Audi A3                 2009
# 3                Audi              2009 Audi A3                 2009
# 4                Audi              2009 Audi A3                 2009
#
#    Engine Information.Engine Statistics.Horsepower  \
# 0                                              250
# 1                                              200
# 2                                              200
# 3                                              200
# 4                                              200
#
#    Engine Information.Engine Statistics.Torque
# 0                                          236
# 1                                          207
# 2                                          207
# 3                                          207
# 4                                          207

# %% [markdown]
# Check the shape of the data

# %%
df.shape
# Out:
# (5076, 18)

# %% [markdown]
# Check columns

# %%
df.columns
# Out:
# Index(['Dimensions.Height', 'Dimensions.Length', 'Dimensions.Width',
#        'Engine Information.Driveline', 'Engine Information.Engine Type',
#        'Engine Information.Hybrid',
#        'Engine Information.Number of Forward Gears',
#        'Engine Information.Transmission', 'Fuel Information.City mpg',
#        'Fuel Information.Fuel Type', 'Fuel Information.Highway mpg',
#        'Identification.Classification', 'Identification.ID',
#        'Identification.Make', 'Identification.Model Year',
#        'Identification.Year',
#        'Engine Information.Engine Statistics.Horsepower',
#        'Engine Information.Engine Statistics.Torque'],
#       dtype='object')

# %% [markdown]
# Use dtypes to check the data types of the columns

# %%
df.dtypes
# Out:
# Dimensions.Height                                   int64
# Dimensions.Length                                   int64
# Dimensions.Width                                    int64
# Engine Information.Driveline                       object
# Engine Information.Engine Type                     object
# Engine Information.Hybrid                            bool
# Engine Information.Number of Forward Gears          int64
# Engine Information.Transmission                    object
# Fuel Information.City mpg                           int64
# Fuel Information.Fuel Type                         object
# Fuel Information.Highway mpg                        int64
# Identification.Classification                      object
# Identification.ID                                  object
# Identification.Make                                object
# Identification.Model Year                          object
# Identification.Year                                 int64
# Engine Information.Engine Statistics.Horsepower     int64
# Engine Information.Engine Statistics.Torque         int64
# dtype: object

# %% [markdown]
# From this we can see that some variables are categorical in nature but have object as a dtype so we convert categorical variables such as Identification.Classification, Fuel Information.Fuel Type

# %%
df["Identification.Classification"] = pd.Categorical(df["Identification.Classification"])
df["Fuel Information.Fuel Type"] = pd.Categorical(df["Fuel Information.Fuel Type"])
df["Engine Information.Driveline"] = pd.Categorical(df["Engine Information.Driveline"])

# %% [markdown]
# Count unique values with nunique

# %%
df.nunique()
# Out:
# Dimensions.Height                                   198
# Dimensions.Length                                   208
# Dimensions.Width                                    138
# Engine Information.Driveline                          4
# Engine Information.Engine Type                      535
# Engine Information.Hybrid                             1
# Engine Information.Number of Forward Gears            5
# Engine Information.Transmission                      11
# Fuel Information.City mpg                            27
# Fuel Information.Fuel Type                            4
# Fuel Information.Highway mpg                         34
# Identification.Classification                         2
# Identification.ID                                  5030
# Identification.Make                                  47
# Identification.Model Year                           918
# Identification.Year                                   4
# Engine Information.Engine Statistics.Horsepower     216
# Engine Information.Engine Statistics.Torque         217
# dtype: int64

# %% [markdown]
# We can see that there are 5030 unique IDs but 5076 records so we need to remove duplicate rows based on ID.

# %%
df.drop_duplicates(subset='Identification.ID', keep='first', inplace=True)

df.shape
# Out:
# (5030, 18)

# %% [markdown]
# Use unique to visualise unique values

# %%
for column in df.columns:
    print(column, df[column].unique())
# Out:
# Dimensions.Height [140  91 201 147 172 226 148 112 120  77  22  24  82  85  43  35 167 193
#   99 110 118 108 185 195 119 190 203 213 177 175  66  93 247  10 143 152
#   45 156 155  58 206 205 191 186 208 139 218 124 109 117 210  13 101 103
#  102 104  92  61  19  37 188 179 194 224 132  88  38   1  23 189 168 223
#  137 198 180 164 115 135 141 159 170  33 150  96 165 200 162 228 238 157
#  144  74 239 127  36 220 173 163 126 158  41  52  54   5  89 169 212 214
#  114 244 142 134  71  94 231 111 221 216 138  64 236 183  46 254 125  26
#  252 229   3 233  17 246  28 178  11  57  79 196 181   9  27 230 222  20
#   30 128 166 255 161 184 197  60 160  12 207  51  25  55  34 211 242   8
#  249  95  69  63  80  48  40 146  73   6  39  16 130 153 107 100  78 217
#  145  97   7 133   2 234  49  62  42  44  50 105  75 199 113 174  32 241]
# Dimensions.Length [143  17 221  96  63 243  12  22 140  60 102 215  52  75 168 155  34 195
#  199 170   7 230 123  19  14 169 216 200 196 240 150  95  57 226  66  71
#  198 181  93 242 197 220 202  24 234 232 207  86 187  61 177 134  87  20
#   42 204 214 190  79  69 105 147  21 225 249  18 206  16 183  45  30 223
#  'BMW 3.0L 6 Cylinder 300 hp 300 ft-lbs'
#  'Mercedes-AMG 6.2L 8 Cylinder 507 hp 465 ft-lbs'
#  'Mercedes-Benz 6.2L 8 Cylinder 507 hp 465 ft-lbs'
#  'Hyundai 3.8L 6 Cylinder 265 hp 262 ft-lbs'
#  'Hyundai 2.4L 4 Cylinder 162 hp 162 ft-lbs'
#  'Hyundai 3.8L 6 Cylinder 225 hp 255 ft-lbs'
#  'Hyundai 2.4L 4 Cylinder 160 hp 157 ft-lbs'
#  'Cadillac 6.2L 8 Cylinder 556 hp 551 ft-lbs S-charged'
#  'Mitsubishi 2.0L 4 Cylinder 148 hp 146 ft-lbs'
#  'Mitsubishi 2.4L 4 Cylinder 168 hp 167 ft-lbs'
#  'Mitsubishi 2.0L 4 Cylinder 152 hp 146 ft-lbs'
#  'Cadillac 3.0L 6 Cylinder 270 hp 223 ft-lbs'
#  'Cadillac 3.6L 6 Cylinder 304 hp 273 ft-lbs'
#  'Toyota 4.6L 8 Cylinder 310 hp 327 ft-lbs'
#  'Toyota 5.7L 8 Cylinder 381 hp 401 ft-lbs FFV'
#  'Infiniti 3.5L 6 cylinder 297 hp 253 ft-lbs'
#  'BMW 3.0L 6 cylinder 320 hp 332 ft-lbs Turbo'
#  'Chevrolet 6.2L 8 Cylinder 638 hp 604 ft-lbs S-charged'
#  'Nissan 2.5L 4 cylinder 200 hp 180 ft-lbs'
#  'Nissan 2.0L 4 cylinder 140 hp 147 ft-lbs'
#  'Mercedes-Benz 3.0L 6 Cylinder 210 hp 400 ft-lbs Turbo Diesel'
#  'Mercedes-AMG 5.4L 8 Cylinder 500 hp 516 ft-lbs S-Charged'
#  'Cadillac 6.2L 8 Cylinder 403 hp 417 ft-lbs FFV'
#  'Mitsubishi 2.0L 4 Cylinder 291 hp 300 ft-lbs Turbo'
#  'Mitsubishi 2.0L 4 Cylinder 148 hp 145 ft-lbs'
#  'Mitsubishi 3.0L 6 Cylinder 230 hp 215 ft-lbs'
#  'Cadillac 4.6L 8 Cylinder 275 hp 295 ft-lbs'
#  'Cadillac 4.6L 8 Cylinder 292 hp 288 ft-lbs'
#  'BMW 3.0L 6 cylinder 265 hp 425 ft-lbs Turbo'
#  'Mercedes-Benz 4.6L 8 Cylinder 335hp 339ft-lbs'
#  'Ford 2.5L 4 cylinder 171hp 171 ft-lbs'
#  'Chevrolet 1.8L 4 Cylinder 138 hp 123 ft-lbs'
#  'Chevrolet 1.4L 4 Cylinder 138 hp 148 ft-lbs Turbo'
#  'Chevrolet 1.8L 4 Cylinder 136 hp 123 ft-lbs'
#  'Cadillac 3L 6 Cylinder 265 hp 223 ft-lbs'
#  'Nissan 1.6L 4 Cylinder 107 hp 111 ft-lbs'
#  'Cadillac 6.0L 8 Cylinder 332 hp 367 ft-lbs Hybrid'
#  'Dodge 2.4L 4 Cylinder 173 hp 166 ft-lbs'
#  'Dodge 3.6L 6 Cylinder 283 hp 260 ft-lbs FFV'
#  'Honda 2.4L 4 Cylinder 180 hp 161 ft-lbs'
#  'Honda 2.4L 4 Cylinder 166 hp 161 ft-lbs'
#  'Cadillac 2.8L 6 Cylinder 300 hp 295 ft-lbs Turbo'
#  'Nissan 4.0L 6 Cylinder 261 hp 281 ft-lbs'
#  'BMW 4.8L 8 cylinder 360hp 360 ft-lbs'
#  'Mercedes-AMG 6.2L 8 Cylinder 503 hp 465 ft-lbs'
#  'Toyota 3.5L 6 Cylinder 266hp 245 ft-lbs.'
#  'BMW 4.4L 8 cylinder 400 hp 450 ft-lbs Turbo'
#  'Nissan 1.6L 4 Cylinder 109 hp 107 ft-lbs'
#  'Mercedes-AMG 6.0L 12 Cylinder 604 hp 738 ft-lbs Turbo'
#  'Mercedes-Benz 3.5L 6 Cylinders 300 hp 265 ft-lbs'
#  'Mercedes-AMG 5.4L 8 Cylinders 355 hp 376 ft-lbs'
#  'Lincoln 3.7L 6 Cylinder 273 hp 270 ft-lbs.'
#  'Lincoln 3.5L 6 Cylinder 355 hp 350 ft-lbs Turbo'
#  'Lincoln 3.7L 6 Cylinder 268 hp 267 ft-lbs'
#  'Lincoln 3.7L 6 Cylinder 305 hp 280 ft-lbs'
#  'Lincoln 3.5L 6 Cylinder 265 hp 250 ft-lbs'
#  'Lincoln 3.5L 6 Cylinder 263 hp 249 ft-lbs'
#  'Mazda 1.5L 4 Cylinder 100 hp 98 ft-lbs'
#  'Mazda 2.0L 4 Cylinder 148 hp 135 ft-lbs'
#  'Mazda 2.5L 4 Cylinder 167 hp 168 ft-lbs'
#  'Ford 3.5L 6 Cylinder 290 hp 255 ft-lbs'
#  'Mazda 2.3L 4 Cylinder 263 hp 280 ft-lbs Turbo'
#  'Ford 4.0L 6 Cylinder 210 hp 254 ft-lbs'
#  'Ford 4.6L 8 Cylinder 292 hp 315 ft-lbs'
#  'Mazda 2.5L 4 Cylinder 157 hp 163 ft-lbs'
#  'Mazda 2.3L 4 Cylinder 153 hp 148 ft-lbs'
#  'Honda 3.5L 6 Cylinder 250 hp 253 ft-lbs'
#  'Mazda 2.5L 4 Cylinder 170hp 167 ft-lbs'
#  'Mazda 3.7L 6 Cylinder 272 hp 269 ft-lbs'
#  'Lincoln 5.4L 8 Cylinder 310 hp 365 ft-lbs FFV'
#  'Lincoln 4.6L 8 Cylinder 239 hp 287 ft-lbs FFV'
#  'Infiniti 3.5L 6 cylinder 303 hp 262 ft-lbs'
#  'Infiniti 5.0L 8 cylinder 390 hp 369 ft-lbs'
#  'infiniti 3.5L 6 Cylinder 302 hp 258 ft-lbs Hybrid'
#  'Cadillac 3.6L 6 Cylinder 302 hp 272 ft-lbs'
#  'Dodge 2.0L 4 Cylinder 158 hp 141  ft-lbs'
#  'Dodge 2.4L 4 Cylinder 172 HP 165 FT-LBS'
#  'Dodge 3.6L 6 Cylinder 305 hp 268 ft-lbs'
#  'Dodge 5.7L 8 Cylinder 379 hp 410 ft-lbs'
#  'Dodge 6.4L 8 Cylinder 470 hp 470 ft-lbs'
#  'Infiniti 4.5L 6 cylinder 325hp 336 ft-lbs'
#  'Dodge 3.5L 6 Cylinder 250 hp 250 ft-lbs'
#  'Dodge 6.1L 8 Cylinder 425 HP 420 FT-LBS'
#  'Dodge 5.7L 8 Cylinder 372 hp 400 ft-lbs'
#  'Infiniti 3.7L 6 cylinder 330 hp 270 ft-lbs'
#  'Infiniti 5.6L 8 Cylinder 420 hp 417 ft-lbs'
#  'Toyota 2.7L 4 Cylinder 182 hp 182 ft-lbs'
#  'Toyota 3.5L 6 Cylinder 268 hp 246 ft-lbs'
#  'Cadillac 4.6L 8 Cylinder 320 hp 315 ft-lbs'
#  'Ford 5.4L 8 cylinder 310 hp 365 ft-lbs FFV'
#  'Dodge 3.6L 6 Cylinder 292 hp 260 ft-lbs'
#  'Dodge 5.7L 8 Cylinder 370 hp 395 ft-lbs'
#  'GMC 3.6L 6 Cylinder 288 hp 270 ft-lbs.'
#  'Dodge 5.7L 8 Cylinder 368 hp 395 ft-lbs'
#  'Dodge 3.6L 6 Cylinder 290 hp 260 ft-lbs FFV'
#  'Mazda 2.0L 4 Cylinder 167 hp 140 ft-lbs'
#  'Mazda 2.0L 4 Cylinder 158 hp 140 ft-lbs'
#  'Mazda 1.3L R2 232 hp 159 ft-lbs' 'Mazda 1.3L R2 212 hp 159 ft-lbs'
#  'Infiniti 2.5L 6 Cylinder 218 hp 187 ft-lbs'
#  'Toyota 1.5L 4 Cylinder 106 hp 103 ft-lbs'
#  'Chevrolet 2.4L 4 Cylinder 182 hp 172 ft-lbs FFV'
#  'Chevrolet 3.0L 6 Cylinder 264 hp 222 ft-lbs FFV'
#  'Nissan 2.5L 4 cylinder 170 hp 175 ft-lbs'
#  'Chevrolet 2.4L 4 Cylinder 182 hp 172 ft-lbs'
#  'Chevrolet 3.0L 6 Cylinder 264 hp 222 ft-lbs'
#  'Ford 2.0L 4 Cylinder 136 hp 128 ft-lbs'
#  'Ford 4.6L 8 Cylinder 224 hp 265 ft-lbs FFV'
#  'Porsche 3.8L 6 cylinder 385 hp 310 ft-lbs'
#  'Porsche 3.6L 6 cylinder 345 hp 288 ft-lbs'
#  'Porsche 3.8L 6 Cylinder 500 hp 480 ft-lbs Turbo'
#  'Porsche 3.8L 6 Cylinder 408 hp 310 ft-lbs'
#  'Infiniti 3.7L 6 Cylinder 325 hp 267 ft-lbs'
#  'Mazda 2.5L 4 Cylinder 171 hp 171 ft-lbs'
#  'Mazda 3.0L 6 Cylinder 240 hp 223 ft-lbs FFV'
#  'Dodge 5.7L 8 Cylinder 360 hp 390 ft-lbs'
#  'Jeep 3.7L 6 Cylinder 210 hp 235 ft-lbs'
#  'Jeep 5.7L 8 Cylinder 357 hp 389 ft-lbs'
#  'Jeep 2.0L 4 Cylinder 158 hp 141 ft-lbs'
#  'Jeep 2.4L 4 Cylinder 172 hp 165 ft-lbs'
#  'GMC 2.9L 4 Cylinder 185 hp 190 ft-lbs'
#  'GMC 3.7L 5 Cylinder 242 hp 242 ft-lbs'
#  'GMC 2.4L 4 Cylinder 182 hp 172 ft-lbs'
#  'GMC 5.3L 8 Cylinder 300 hp 320 ft-lbs'
#  'Dodge 4.0L 6 Cylinder 251 hp 259 ft-lbs'
#  'Dodge 3.8L 6 Cylinder 197 hp 230 ft-lbs'
#  'Dodge 3.3L 6 Cylinder 175 hp 205 ft-lbs FFV'
#  'Dodge 3.6L 6 Cylinder 280 hp 260 ft-lbs'
#  'Infiniti 3.7L 6 cylinder 328 hp 269 ft-lbs'
#  'BMW 6.0L 12 cylinder 535hp 550 ft-lbs Turbo'
#  'BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo'
#  'Dodge 3.5L 6 Cylinder 235 hp 232 ft-lbs'
#  'BMW 4.4L 8 cylinder 455hp 515 ft-lbs Turbo Hybrid'
#  'Dodge 4.0L 6 Cylinder 260 HP 265 FT-LBS'
#  'BMW 4.4L 8 cylinder 500hp 516 ft-lbs Tr-charged'
#  'Lexus 3.5L 6 Cylinder 272hp 254 lbs-ft VVT-i'
#  'Dodge 3.7L 6 Cylinder 210 hp 235 ft-lbs'
#  'Chevrolet 4.3L 6 Cylinder 195 hp 525 ft-lbs'
#  'Infiniti 3.7L 6 Cylinder 348 hp 276 ft-lbs'
#  'GMC 3.0L 6 Cylinder 264 hp 222 ft-lbs FFV'
#  'GMC 5.3L 8 Cylinder 320 hp 335 ft-lbs FFV'
#  'GMC 6.2L 8 Cylinder 403 hp 417 ft-lbs FFV'
#  'GMC 6.0L 8 Cylinder 352 hp 382 ft-lbs'
#  'Infiniti 5.6L 8 cylinder 320hp 393 ft-lbs'
#  'Infiniti 5.6L 8 Cylinder 400 hp 413 ft-lbs'
#  'Acura 3.7L 6 Cylinder 300 hp 270 ft-lbs'
#  'Acura 2.3L 4 Cylinder 240 hp 260 ft-lbs TURBO'
#  'BMW 4.0L 8 cylinder 414 hp 295 ft-lbs'
#  'Acura 3.7L 6 Cylinder 300 hp 271 ft-lbs'
#  'Nissan 2.0L 4 cylinder 135 hp 142 ft-lbs'
#  'Acura 2.4L 4 Cylinder 201 hp 170 ft-lbs'
#  'Acura 2.4L 4 Cylinder 201 hp 172 ft-lbs'
#  'GMC 6.0L 8 Cylinder 332 hp 367 ft-lbs Hybrid'
#  'GMC 5.3L 8 Cylinder 310 hp 334 ft-lbs FFV'
#  'Porsche 3.4L 6 Cylinder 310 hp 266 ft-lbs'
#  'Porsche 3.4L 6 Cylinder 320 hp 273 ft-lbs'
#  'Porsche 2.9L 6 Cylinder 255 hp 214 ft-lbs'
#  'Dodge 8.4L 10 Cylinder 600 hp 560 ft-lbs'
#  'Porsche 3.0L 6 Cylinder 380 hp 427 ft-lbs Hybrid'
#  'Porsche 3.6L 6 Cylinder 300 hp 295 ft-lbs'
#  'Porsche 4.8L 8 cylinder 500 hp 516 ft-lbs Turbo'
#  'Porsche 4.8L 8 Cylinder 400 hp 369 ft-lbs'
#  'Porsche 4.8L 8 cylinder 550hp 553 ft-lbs Turbo'
#  'Porsche 4.8L 8 cylinder 405 hp 369 ft-lbs'
#  'Porsche 3.6L 6 cylinder 290 hp 273 ft-lbs'
#  'Porsche 4.8L 8 cylinder 385 hp 369 ft-lbs'
#  'GMC 4.8L 8 Cylinder 280 hp 295 ft-lbs FFV'
#  'GMC 6.0L 8 Cylinder 324 hp 373 ft-lbs FFV'
#  'Chevrolet 2.2L 4 Cylinder 155 hp 150 ft-lbs FFV'
#  'Chevrolet 2.4L 4 Cylinder 172 hp 167 ft-lbs FFV'
#  'Chevrolet 2.0L 4 Cylinder 260 hp 260 ft-lbs Turbo'
#  'Porsche 2.9L 6 Cylinder 265 hp 221 ft-lbs'
#  'Porsche 3.4L 6 Cylinder 330 hp 273 ft-lbs'
#  'Chevrolet 3.6L 6 Cylinder 300 hp 262 ft-lbs FFV'
#  'Chevrolet 3.5L 6 Cylinder 211 hp 216 ft-lbs FFV'
#  'Chevrolet 3.9L 6 Cylinder 230 hp 235 ft-lbs FFV'
#  'Subaru 2.5L 4 cylinder 224 hp 226 ft-lbs Turbo'
#  'Subaru 2.5L 4 Cylinder 170 hp 174 ft-lbs'
#  'Buick 3.6L 6 Cylinder 288 hp 270 ft-lbs'
#  'Suzuki 2.4L 4 Cylinder 166 hp 162 ft-lbs'
#  'Buick 2.4L 4 Cylinder 182 hp 172 ft-lbs Hybrid'
#  'Buick 3.6L 6 Cylinder 280 hp 259 ft-lbs'
#  'Buick 3.0L 6 Cylinder 252 hp 215 ft-lbs'
#  'Buick 3.0L 6 Cylinder 255 hp 217 ft-lbs'
#  'Suzuki 3.2L 6 Cylinder 230 hp 213 ft-lbs'
#  'Honda 3.5L 6 Cylinder 248 hp 250 ft-lbs'
#  'GMC 4.3L 6 Cylinder 195 hp 260 ft-lbs'
#  'GMC 4.8L 8 Cylinder 302 hp 305 ft-lbs FFV'
#  'Honda 3.5L 6 Cylinder 244 hp 240 ft-lbs'
#  'Honda 3.5L 6 Cylinder 244 hp 245 ft-lbs'
#  'Suzuki 2.4L 4 Cylinder 185 hp 170 ft-lbs'
#  'Saab 2.0L 4 Cylinder 210 hp 221 ft-lbs Turbo'
#  'Suzuki 2.0L 4 Cylinder 150 hp 140 ft-lbs'
#  'Subaru 2.5L 4 cylinder 170 hp 170 ft-lbs'
#  'Lexus 3.5L 6 Cylinder 268 hp 248 ft-lbs'
#  'Lexus 3.5L 6 Cylinder 303hp 274ft-lbs'
#  'Lexus 4.6L 8 Cylinder 342hp 339ft-lbs'
#  'Subaru 2.0L 4 Cylinder 148 hp 145 ft-lbs'
#  'Buick 3.9L 6 Cylinder 227 hp 237 ft-lbs FFV'
#  'Buick 4.6L 8 Cylinder 292 hp 288 ft-lbs'
#  'Buick 2.0L 4 Cylinder 220 hp 258 ft-lbs FFV'
#  'Aston Martin 5.9L 12 Cylinder 470 hp 443 ft-lbs'
#  'Jeep 3.6L 6 Cylinder 290 hp 260 ft-lbs FFV'
#  'Jeep 5.7L 8 Cylinder 360 hp 390 ft-lbs'
#  'Subaru 2.5L 4 cylinder 265 hp 244 ft-lbs Turbo'
#  'Subaru 2.5L 4 cylinder 305 hp 290 ft-lbs Turbo'
#  'Jeep 6.1L 8 Cylinder 420 hp 420 ft-lbs'
#  'Porsche 3.6L 6 Cylinder 620 hp 516 ft-lbs Turbo'
#  'Land Rover 3.2L 6 Cylinder 230 hp 234 ft-lbs'
#  'Land Rover 5.0L 8 Cylinder 375 hp 375 ft-lbs'
#  'Land Rover 5.0 8 Cylinder 510 hp 461 ft-lbs S-Charged'
#  'Land Rover 2.0L 4 Cylinder 240 hp 251 ft-lbs'
#  'Chrysler 2.4L 4 cylinder 173 hp 166 ft-lbs'
#  'Chrysler 3.6L 6 cylinder 283 hp 260 ft-lbs FFV'
#  'Ferrari 5.7L 12 Cylinder 540 hp 434 ft-lbs'
#  'Chrysler 2.7L 6 cylinder 186 hp 191 ft-lbs FFV'
#  'Chrysler 3.5L 6 cylinder 235 hp 232 ft-lbs'
#  'Scion 2.5L 4 Cylinder 180hp 173ft-lbs'
#  'Scion 2.4L 4 Cylinder 161hp 162ft-lbs'
#  'Mini 1.6L 4 Cylinder 121 hp 114 ft-lbs'
#  'Mini 1.6L 4 Cylinder 181 hp 177 ft-lbs Turbo'
#  'MINI 1.6L 4 Cylinder 208 hp 192 ft-lbs Turbo'
#  'MINI 1.6L 4 Cylinder 118 hp 114 ft-lbs'
#  'MINI 1.6L 4 Cylinder 172 hp 177 ft-lbs Turbo'
#  'Jaguar 5.0L 8 Cylinder 385 hp 380 ft-lbs'
#  'Jaguar 5.0L 8 Cylinder 470 hp 424 ft-lbs S-Charged'
#  'Jaguar 5.0L 8 Cylinder 510 hp 461 ft-lbs S-Charged'
#  'Chevrolet 2.4L 4 Cylinder 169 hp 160 ft-lbs'
#  'Chevrolet 3.6L 6 Cylinder 252 hp 251 ft-lbs'
#  'Aston Martin 5.9L 12 Cylinder 510 hp 420 ft-lbs'
#  'Chrysler 3.6L 6 cylinder 292 hp 260 ft-lbs FFV'
#  'Chrysler 5.7L 8 cylinder 363 hp 394 ft-lbs'
#  'Chrysler 2.7L 6 cylinder 178 hp 190 ft-lbs'
#  'Chrysler 3.5L 6 cylinder 250 hp 250 ft-lbs'
#  'Chrysler 5.7L 8 cylinder 360 hp 389 ft-lbs'
#  'Chrysler 6.1L 8 cylinder 425hp 420 ft-lbs'
#  'Chrysler 3.8L 6 cylinder 197hp 230 ft-lbs'
#  'Chrysler 4.0L 6 cylinder 251hp 259 ft-lbs'
#  'Jaguar 4.2L 8 Cylinder 300 hp 310 ft-lbs'
#  'Lotus 1.8L 4 Cylinder 189 hp 133 ft-lbs'
#  'Lotus 1.8L 4 Cylinder 217 hp 155 ft-lbs'
#  'Lotus 1.8L 4 Cylinder 218 hp 156 ft-lbs S-charged'
#  'Lotus 3.5L 6 Cylinder 276 hp 258 ft-lbs'
#  'Chevrolet 2.4L 4 Cylinder 170 hp 158 ft-lbs FFV'
#  'Lotus 1.8L 4 Cylinder 240 hp 170 ft-lbs S-charged'
#  'Lotus 1.8L 4 Cylinder 257 hp 174 ft-lbs S-charged'
#  'Chevrolet 1.8L 4 Cylinder 138 hp 125 ft-lbs'
#  'Chevrolet 2.4L 4 Cylinder 164 hp 159 ft-lbs Hybrid'
#  'Maserati 4.2L 8 Cylinder 405 hp 339 ft-lbs'
#  'Maserati 4.7L 8 Cylinder 433 hp 361 ft-lbs'
#  'Maserati 4.2L 8 Cylinder 400 hp 339 ft-lbs'
#  'Maserati 4.7L 8 Cylinder 430 hp 361 ft-lbs'
#  'Maserati 4.7L 8 Cylinder 440 hp 361 ft-lbs'
#  'Jeep 3.8L 6 Cylinder 202 hp 237 ft-lbs'
#  'Jeep 3.8L 6 Cylinder 205 hp 240 ft-lbs'
#  'Maserati 4.7L 8 Cylinder 425 hp 361 ft-lbs'
#  'Honda 3.5L 6 Cylinder 250 hp 247 ft-lbs'
#  'Mercury 4.6L 8 cylinder 224hp 275 ft-lbs FFV'
#  'Mercury 2.5L 4 cylinder 171 hp 171 ft-lbs'
#  'Mercury 3.0L 6 Cylinder 240 hp 223 ft-lbs FFV'
#  'Chrysler 3.3L 6 cylinder 175hp 205 ft-lbs FFV'
#  'BMW 5.0L 10 cylinder 500hp 383 ft-lbs'
#  'BMW 3.0L 6 cylinder 260 hp 225 ft-lbs'
#  'Toyota 2.5L 4 Cylinder 178 hp 170 ft-lbs'
#  'BMW 3.0L 6 cylinder 240hp 221 ft-lbS'
#  'BMW 4.8L 8 cylinder 350hp 350 ft-lbs'
#  'Chevrolet 5.3L 8 Cylinder 320 hp 335 ft-lbs FFV'
#  'Chevrolet 6.0L 8 Cylinder 352 hp 382 ft-lbs'
#  'Dodge 3.7L 6 Cylinder 215 hp 235 ft-lbs'
#  'Dodge 4.7L 8 Cylinder 310 hp 330 ft-lbs FFV'
#  'Dodge 5.7L 8 Cylinder 390 hp 407 ft-lbs'
#  'GMC 5.3L 8 Cylinder 315 hp 335 ft-lbs FFV'
#  'Chevrolet 6.0L 8 Cylinder 332 hp 367 ft-lbs Hybrid'
#  'BMW 3.0L 6 Cylinder 255hp 220 ft-lbs'
#  'Chevrolet 3.6L 6 Cylinder 281 hp 266 ft-lbs'
#  'Chevrolet 3.6L 6 Cylinder 288 hp 270 ft-lbs'
#  'Saab 3.0L 6 Cylinder 265 hp 223 ft-lbs'
#  'Saab 2.8L 6 Cylinder 300 hp 295 ft-lbs Turbo'
#  'Aston Martin 6.0L 510 hp 420 ft-lbs'
#  'Saab 2.0L 4 Cylinder 220 hp 258 ft-lbs FFV'
#  'Mercury 2.5L 4 Cylinder 175 hp 172 ft-lbs'
#  'Aston Martin 4.7L 8 cylinder 420 hp 346 ft-lbs'
#  'Subaru 3.6L 6 cylinder 256 hp 247 ft-lbs'
#  'Subaru 2.5L 4 cylinder 265 hp 258 ft-lbs Turbo'
#  'Lexus 2.5L 6 Cylinder 204 hp 185 ft-lbs'
#  'Lexus 3.5L 6 Cylinder 306 hp 277 ft-lbs'
#  'Toyota 2.7L 4 Cylinder 159 hp 180 ft-lbs'
#  'Toyota 4.0L 6 Cylinder 236 hp 266 ft-lbs'
#  'Chevrolet 3.7L 5 Cylinder 242 hp 242 ft-lbs'
#  'Chevrolet 5.3L 8 Cylinder 300 hp 320 ft-lbs'
#  'Scion 2.4L 4 Cylinder 158 hp 162 ft-lbs.'
#  'Scion 1.8L 4 Cylinder 128 hp 125 ft-lbs.'
#  'Aston Martin 5.9L 12 Cylinder 490 hp 420 ft-lbs'
#  'Suzuki 4.0L 6 Cylinder 261 hp 281 ft-lbs'
#  'Suzuki 2.5L 4 Cylinder 152 hp 171 ft-lbs'
#  'Nissan 2.5L 4 Cylinder 152 hp 171 ft-lbs'
#  'Ford 2.3L 4 Cylinder 143 hp 154 ft-lbs'
#  'Ford 4.0L 6 Cylinder 207 hp 238 ft-lbs'
#  'Chevrolet 5.3L 8 Cylinder 315 hp 338 ft-lbs FFV'
#  'Lexus 5L 8 Cylinder 416hp 371 ft-lbs'
#  'Lexus 5.7L 8 Cylinder 383hp 403 ft-lbs'
#  'Ford 4.6L 8 cylinder 225 hp 286 ft-lbs FFV'
#  'Ford 5.4L 8 cylinder 255 hp 350 ft-lbs FFV'
#  'Ford 6.8L 10 cylinder 305 hp 420 ft-lbs'
#  'Buick 3.6L 6 Cylinder 303 hp 264 ft-lbs FFV'
#  'Dodge 4.7L 8 Cylinder 302 hp 329 ft-lbs FFV'
#  'Buick 2.0L 4 Cylinder 270 hp 295 ft-lbs Turbo'
#  'Chevrolet 6.2L 8 Cylinder 403 hp 417 ft-lbs FFV'
#  'Chevrolet 5.3L 8 Cylinder 315 hp 335 ft-lbs FFV'
#  'Ford 5.0L 8 Cylinder 360 hp 380 ft-lbs FFV'
#  'Ford 3.5L 6 Cylinder 365 hp 420 ft-lbs'
#  'Ford 6.2L 8 Cylinder 411 hp 434 ft-lbs'
#  'Ford 3.7L 6 Cylinder 302 hp 278 ft-lbs FFV'
#  'Ford 4.6L 8 cylinder 248 hp 294 ft-lbs'
#  'Ford 4.6L 8 cylinder 292 hp 320 ft-lbs'
#  'BMW 3.0L 6 cylinder 240hp 230 ft-lbs'
#  'Lexus 5.0L 8 Cylinder 416 hp 371 ft-lbs'
#  'Audi 6.3L 12 Cylinder 500 hp 463 ft-lbs'
#  'Audi 2.5L 5 Cylinder 360 hp 343 ft-lbs Turbo'
#  'Lexus 3.5L 6 Cylinder 270 hp 248 ft-lbs' 'Lexus 4.8L 552 hp 354 ft-lbs'
#  'Jeep 6.4L 8 Cylinder 465 hp 465 ft-lbs'
#  'Mazda 2L 4 Cylinder 148Hp 135 ft-lbs'
#  'Mazda 2.0L 4 Cylinder 155 hp 148 lb-ft'
#  'Dodge 5.7L 8 Cylinder 376 hp 410 ft-lbs'
#  'Mazda 2.0L 4 Cylinder 167 hp 158 ft-lbs'
#  'Dodge 3.6L 6 Cylinder 283 hp 260 ft-lbs'
#  'Kia 1.6L 4 Cylinder 138 hp 123 ft-lbs'
#  'Kia 2.0L 4 Cylinder 164 hp 148 ft-lbs'
#  'Volkswagen 3.0L 6 Cylinder 225 hp 406 ft-lbs Turbo Diesel'
#  'Volkswagen 3.0L 6 Cylinder 380 hp 425 ft-lbs Hybrid'
#  'Honda 2.4L 4 Cylinder 201 hp 170 ft-lbs'
#  'Volkswagen 2.0L 4 Cylinder 256 hp 243 ft-lbs Turbo'
#  'Cadillac 3.6L 6 Cylinder 318 hp 275 ft-lbs'
#  'Jaguar 5.0L 8 Cylinder 550 hp 502 ft-lbs S-charged'
#  'Volkswagen 3.6L 6 Cylinder 283 hp 260 ft-lbs FFV'
#  'Jeep 3.6L 6 Cylinder 280 hp 260 lb-ft'
#  'Cadillac 3.6L  6 Cylinder 308 hp 265 ft-lbs FFV'
#  'Land Rover 5.0L 8 Cylinder 510 hp 461 ft-lbs S-charged'
#  'BMW 2.0L 4 Cylinder 240 hp 260 ft-lbs Turbo'
#  'Subaru 2.0L 4 Cylinder 148 hp 145 ft-lbs PZEV'
#  'Buick 2.4L 4 Cylinder 180 hp 171 ft-lbs FFV'
#  'Suzuki 2.4L 4 Cylinder 180 hp 170 ft-lbs'
#  'Aston Martin 4.7L 8 Cylinder 430 hp 361 ft-lbs'
#  'Saab 2.0L 4 Cylinder 220 hp 258 ft-lbs Turbo FFV'
#  'Lincoln 3.7L 6 Cylinder 274 hp 270 ft-lbs'
#  'Bentley 6.8L 8 Cylinder 505 hp 752 ft-lbs Turbo'
#  'Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs']
# Engine Information.Hybrid [ True]
# Engine Information.Number of Forward Gears [6 5 4 7 8]
# Engine Information.Transmission ['6 Speed Automatic Select Shift' '6 Speed Manual' '5 Speed Manual'
#  '4 Speed Automatic' '6 Speed Automatic' '5 Speed Automatic'
#  '5 Speed Automatic Select Shift' '7 Speed Automatic Select Shift'
#  '8 Speed Automatic Select Shift' '7 Speed Automatic'
#  '4 Speed Automatic Select Shift']
# Fuel Information.City mpg [18 22 21 16 17 13 14 20 12  9  8 10 15 11 19 29 38 28 23 26 25 24 30 27
#  36 31 35]
# Fuel Information.Fuel Type ['Gasoline', 'E85', 'Diesel fuel', 'Compressed natural gas']
# Categories (4, object): ['Compressed natural gas', 'Diesel fuel', 'E85', 'Gasoline']
# Fuel Information.Highway mpg [ 25  28  30  27  26  18  20  29  17  12  13  19  15  14  22  24  31  21
#   23  38  37  32  33  36  35  34  41  16  42  40  39 223  11  43]
# Identification.Classification ['Automatic transmission', 'Manual transmission']
# Categories (2, object): ['Automatic transmission', 'Manual transmission']
# Identification.ID ['2009 Audi A3 3.2' '2009 Audi A3 2.0 T AT' '2009 Audi A3 2.0 T' ...
#  '2012 Lamborghini Gallardo LP 560-4 Spyder' '2012 BMW 740i Sedan'
#  '2012 BMW 740Li Sedan']
# Identification.Make ['Audi' 'Acura' 'BMW' 'Chevrolet' 'Nissan' 'Volvo' 'Bentley' 'Toyota'
#  'Honda' 'Ford' 'Rolls-Royce' 'Volkswagen' 'Maybach' 'Lamborghini' 'Lexus'
#  'Hyundai' 'Mercedes' 'BMW Motorrad' 'Kia' 'AMG' 'Mazda' 'Mercedes-Benz'
#  'Mercedes-AMG' 'Mitsubishi' 'Cadillac' 'Infiniti' 'Dodge' 'Lincoln' 'GMC'
#  'Porsche' 'Jeep' 'Subaru' 'Buick' 'Suzuki' 'Saab' 'Aston Martin'
#  'Grand Cherokee' 'Land Rover' 'Chrysler' 'Ferrari' 'Scion' 'MINI'
#  'Jaguar' 'Chrysler Group LLC' 'Lotus' 'Maserati' 'Mercury']
# Identification.Model Year ['2009 Audi A3' '2009 Audi A5' '2009 Audi Q7' '2009 Audi A4 Sedan'
#  '2012 Acura TL' '2010 BMW X5' '2011 BMW X5' '2010 BMW X6' '2011 BMW X6'
#  '2012 Chevrolet Colorado' '2011 Chevrolet Colorado'
#  '2010 Chevrolet Colorado' '2012 Chevrolet Express'
#  '2011 Chevrolet Express' '2010 Chevrolet Express'
#  '2011 Chevrolet Silverado 1500' '2010 Chevrolet Silverado 1500'
#  '2011 Nissan 370Z Coupe' '2010 Nissan 370Z Coupe'
#  '2009 Nissan 370Z Coupe' '2011 Volvo C30' '2010 Volvo C30'
#  '2010 Bentley Brooklands'
#  '2012 Bentley Continental Supersports Convertible'
#  '2012 Bentley Continental Supersports Coupe'
#  '2011 Bentley Continental Supersports Convertible'
#  '2010 Bentley Continental Supersports'
#  '2012 Bentley Continental Flying Spur'
#  '2011 Bentley Continental Flying Spur'
#  '2010 Bentley Continental Flying Spur' '2011 Volvo C70' '2010 Volvo C70'
#  '2010 Volvo S40' '2011 Volvo S40' '2012 Volvo S60' '2011 Volvo S60'
#  '2011 Volvo S80' '2010 Volvo S80' '2011 Volvo V50' '2010 Volvo V50'
#  '2011 Volvo XC60' '2010 Volvo XC60' '2011 Volvo XC70' '2010 Volvo XC70'
#  '2011 Toyota 4Runner' '2011 Volvo XC90' '2010 Volvo XC90'
#  '2010 Volvo V70' '2010 Toyota 4Runner' '2012 Audi A3'
#  '2010 Honda Accord Coupe' '2011 Nissan 370Z Roadster'
#  '2010 Nissan 370Z Roadster' '2011 Audi A3' '2010 Audi A3'
#  '2012 Audi A4 Sedan' '2011 Audi A4 Sedan' '2012 Ford Fiesta Sedan'
#  '2011 Ford Fiesta Sedan' '2010 Audi A4 Sedan' '2012 Audi A4 Avant'
#  '2011 Audi A4 Avant' '2010 Audi A4 Avant' '2011 Honda Accord Coup'
#  '2012 Ford Fiesta Hatchback' '2011 Ford Fiesta Hatchback'
#  '2010 Honda Accord Sedan' '2011 Toyota Avalon' '2010 Toyota Avalon'
#  '2011 Toyota Camry' '2012 Ford Focus Sedan' '2011 Ford Focus Sedan'
#  '2010 Ford Focus Sedan' '2011 Nissan Altima Coupe' '2012 Volvo S80'
#  '2012 Volvo XC60' '2012 Volvo XC70' '2012 Volvo XC90'
#  '2010 Nissan Altima Coupe' '2010 Toyota Camry'
#  '2012 Bentley Continental GT' '2010 Bentley Continental GT'
#  '2010 Ford Focus Coupe' '2011 Bentley Continental GTC'
#  '2010 Bentley Continental GTC' '2010 Bentley Azure T'
#  '2011 Infiniti M' '2011 Toyota Venza' '2012 Infiniti M'
#  '2010 Cadillac STS' '2011 Ford Expedition' '2011 Dodge Charger'
#  '2011 Mazda Mazda6' '2011 GMC Acadia' '2010 Mazda Mazda6'
#  '2010 Dodge Charger' '2011 Dodge Durango' '2010 Ford Expedition'
#  '2011 Mazda MX-5 Miata' '2010 Mazda MX-5 Miata' '2011 Mazda RX-8'
#  '2011 Infiniti G25' '2010 Mazda RX-8' '2010 Toyota Venza'
#  '2011 Toyota Yaris 5-Door Liftback' '2012 Chevrolet Equinox'
#  '2010 Toyota Yaris 5-Door Liftback' '2011 Toyota Yaris 3-Door Liftback'
#  '2011 Chevrolet Equinox' '2010 Toyota Yaris 3-Door Liftback'
#  '2011 Toyota Yaris Sedan' '2012 Ford Transit Connect Van'
#  '2012 Ford Transit Connect Wagon' '2011 Transit Connect Van'
#  '2011 Transit Connect Wagon' '2010 Transit Connect Van'
#  '2010 Transit Connect Wagon' '2010 Ford Crown Victoria'
#  '2011 Porsche 911 Coupe' '2009 Infiniti G37 Convertible'
#  '2011 Mazda Tribute' '2010 Mazda Tribute' '2010 Toyota Yaris Sedan'
#  '2012 Toyota Yaris 3-Door Liftback' '2011 Porsche 911 Cabriolet'
#  '2011 Dodge Grand Caravan' '2010 Jeep Commander' '2011 Jeep Compass'
#  '2010 GMC Acadia' '2011 GMC Canyon' '2010 GMC Terrain' '2010 GMC Canyon'
#  '2010 Infiniti G37 Convertible' '2010 Honda Pilot'
#  '2012 Toyota Yaris 5-Door Liftback' '2012 Toyota Highlander'
#  '2010 Dodge Grand Caravan' '2010 Jeep Compass' '2011 Dodge Journey'
#  '2011 Infiniti G37 Convertible' '2010 Infiniti G37 Sedan'
#  '2010 BMW 6 Series Coup' '2011 Infiniti G37 Sedan' '2009 BMW 7 Series'
#  '2010 BMW 7 Series' '2010 Chevrolet Equinox' '2011 BMW 7 Series'
#  '2010 Dodge Journey' '2011 BMW ActiveHybrid 7 Sedan' '2011 Dodge Nitro'
#  '2011 BMW ALPINA B7 Sedan' '2010 Lexus ES' '2010 Dodge Nitro'
#  '2011 Infiniti G37 Coupe' '2011 Infiniti IPL G Coupe' '2011 GMC Terrain'
#  '2011 GMC Yukon' '2010 Porsche 911 Coupe' '2010 GMC Yukon'
#  '2010 Infiniti G37 Coupe' '2011 GMC Yukon XL' '2010 GMC Yukon XL'
#  '2010 Infiniti QX56' '2011 Infiniti QX56' '2010 Acura MDX'
#  '2011 Acura MDX' '2010 Acura RDX' '2011 Acura RDX'
#  '2010 BMW M3 Convertible' '2010 Acura ZDX' '2011 Acura ZDX'
#  '2011 BMW M3 Convertible' '2010 Acura RL' '2011 Acura RL' '2010 Acura TL'
#  '2010 BMW M3 Coup' '2011 BMW M3 Coup' '2011 Acura TL' '2010 BMW M3 Sedan'
#  '2011 BMW M3 Sedan' '2010 Acura TSX' '2011 Acura TSX'
#  '2011 Acura TSX Sport Wagon' '2011 GMC Yukon Hybrid'
#  '2010 GMC Yukon Hybrid' '2010 Porsche 911 Cabriolet' '2011 GMC Savana'
#  '2011 Porsche Boxster' '2010 Dodge Viper Coup'
#  '2010 Dodge Viper Convertible' '2010 Porsche Boxster'
#  '2011 Porsche Cayenne S Hybrid' '2011 Porsche Cayenne'
#  '2010 Porsche Cayenne' '2011 Chevrolet HHR Wagon'
#  '2010 Chevrolet HHR Wagon' '2011 Chevrolet HHR Panel'
#  '2010 Chevrolet HHR Panel' '2011 Porsche Cayman' '2010 Porsche Cayman'
#  '2012 Chevrolet Impala' '2011 Chevrolet Impala' '2011 Subaru Forester'
#  '2010 Chevrolet Impala' '2011 Buick Enclave' '2010 Buick Enclave'
#  '2011 Suzuki Grand Vitara' '2011 Buick Lacrosse' '2010 Buick Lacrosse'
#  '2010 Suzuki Grand Vitara' '2011 Honda Odyssey' '2010 GMC Sierra 1500'
#  '2010 Honda Odyssey' '2010 GMC Savana' '2011 Suzuki Kizashi'
#  '2010 Suzuki Kizashi' '2011 Saab 9-3 Convertible'
#  '2010 Saab 9-3 Convertible' '2011 Suzuki SX4 Sedan'
#  '2010 Suzuki SX4 Sportback' '2011 Suzuki SX4 Sportback'
#  '2010 Suzuki SX4 Sedan' '2011 Saab 9-3 Sport Sedan'
#  '2010 Subaru Forester' '2011 Lexus ES' '2010 Lexus GS'
#  '2012 Subaru Impreza Sedan' '2011 Buick Lucerne' '2010 Buick Lucerne'
#  '2011 Buick Regal' '2011 Aston Martin DB9 Volante'
#  '2010 Saab 9-3 Sport Sedan' '2011 Jeep Grand Cherokee'
#  '2010 Aston Martin DB9 Volante' '2010 Subaru Impreza WRX Sedan'
#  '2011 Subaru Impreza WRX Sedan' '2010 Subaru Impreza Sedan'
#  '2011 Subaru Impreza Sedan' '2010 Jeep Grand Cherokee'
#  '2011 Jeep Liberty' '2011 Land Rover LR2' '2010 Land Rover LR2'
#  '2011 Land Rover LR4' '2010 Land Rover LR4' '2010 Jeep Liberty'
#  '2011 Land Rover Range Rover' '2010 Land Rover Range Rover'
#  '2012 Land Rover Range Rover Evoque' '2011 Chrysler 200 Convertible'
#  '2010 Ferrari 612 Scaglietti' '2011 Land Rover Range Rover Sport'
#  '2010 Chrysler Sebring Convertible' '2010 Land Rover Range Rover Sport'
#  '2010 Chrysler Sebring Sedan' '2011 Saab 9-3 SportCombi' '2012 Scion tC'
#  '2011 Scion tC' '2010 Scion tC' '2011 Aston Martin DB9 Coup'
#  '2010 Aston Martin DB9 Coup' '2010 Saab 9-3 SportCombi'
#  '2012 MINI Cooper Hardtop' '2011 MINI Cooper Hardtop'
#  '2010 MINI Cooper Hardtop' '2012 MINI Cooper Convertible'
#  '2011 MINI Cooper Convertible' '2010 MINI Cooper Convertible'
#  '2011 Jaguar XJ' '2012 Chevrolet Malibu' '2012 MINI Clubman'
#  '2011 Aston Martin DBS Volante' '2011 MINI Clubman' '2010 MINI Clubman'
#  '2011 Aston Martin Rapide' '2011 Chrysler 200 Sedan'
#  '2011 Jaguar XK Convertible' '2011 Jaguar XK Coup' '2011 Chrysler 300'
#  '2010 Jaguar XK Convertible' '2010 Jaguar XK Coup' '2011 Jaguar XF'
#  '2011 Jeep Patriot' '2010 Chrysler 300' '2011 Chrysler Town and Country'
#  '2010 Chrysler Town and Country' '2010 Jaguar XF' '2010 Jeep Patriot'
#  '2011 Lotus Elise' '2010 Lotus Elise' '2009 Lotus Elise'
#  '2011 Chevrolet Malibu' '2011 Lotus Evora' '2012 MINI Countryman'
#  '2011 MINI Countryman' '2010 Chevrolet Malibu' '2011 Lotus Exige'
#  '2010 Lotus Exige' '2009 Lotus Exige' '2012 Chevrolet Sonic Sedan'
#  '2010 Chevrolet Malibu Hybrid' '2011 Maserati GranTurismo Coup'
#  '2010 Maserati GranTurismo Coup' '2011 Maserati GranTurismo Convertible'
#  '2010 Maserati GranTurismo Convertible' '2011 Maserati Quattroporte'
#  '2011 Jeep Wrangler' '2010 Jeep Wrangler' '2010 Maserati Quattroporte'
#  '2011 Honda Ridgeline' '2010 Honda Ridgeline' '2012 MINI Cooper Coupe'
#  '2011 Mercury Grand Marquis' '2010 Mercury Grand Marquis'
#  '2011 Mercury Mariner' '2010 BMW M6 Convertible' '2010 BMW M6 Coup'
#  '2010 BMW X3' '2012 Toyota Camry' '2011 BMW X3' '2012 Toyota FJ Cruiser'
#  '2012 Chevrolet Sonic Hatchback' '2011 Chevrolet Suburban Half-Ton'
#  '2011 Chevrolet Suburban Three-Quarter-Ton' '2010 Chevrolet Suburban'
#  '2011 Subaru Impreza Hatchback' '2011 Subaru Impreza WRX Hatchback'
#  '2010 Subaru Impreza Hatchback' '2010 Subaru Impreza WRX Hatchback'
#  '2011 Dodge Ram 1500' '2011 GMC Sierra 1500' '2011 Chevrolet Tahoe'
#  '2010 Chevrolet Tahoe' '2011 Chevrolet Tahoe Hybrid'
#  '2010 Chevrolet Tahoe Hybrid' '2010 BMW Z4 Roadster'
#  '2012 Chevrolet Traverse' '2011 BMW Z4 Roadster'
#  '2011 Cadillac Escalade EXT' '2010 Cadillac Escalade EXT'
#  '2011 Saab 9-4X' '2010 Aston Martin Rapide'
#  '2011 Aston Martin V12 Vantage' '2011 Saab 9-5 Sedan'
#  '2010 Saab 9-5 Sedan' '2010 Mercury Mariner' '2011 Chevrolet Traverse'
#  '2010 Chevrolet Traverse' '2011 Mercury Milan' '2010 Mercury Milan'
#  '2011 Lexus GS' '2011 Aston Martin V8 Vantage Roadster'
#  '2010 Aston Martin V8 Vantage Roadster'
#  '2011 Aston Martin V8 Vantage Coup' '2010 Aston Martin V8 Vantage Coup'
#  '2011 Chevrolet Avalanche' '2010 Chevrolet Avalanche'
#  '2011 Subaru Legacy' '2010 Dodge Ram 1500' '2010 Lexus IS'
#  '2011 Lexus IS' '2011 Toyota Tacoma' '2010 Toyota Tacoma' '2012 Scion xB'
#  '2011 Scion xB' '2010 Scion xB' '2011 Scion xD'
#  '2011 Aston Martin Virage Volante' '2010 Scion xD'
#  '2012 Aston Martin Virage Volante' '2011 Toyota Tundra' '2010 Lexus IS C'
# Identification.Year [2009 2012 2010 2011]
# Engine Information.Engine Statistics.Horsepower [250 200 265 350 280 211 305 555 185 310 324 195 302 227 530 621 552 600
#  168 300 325 240 311 281 235 270 157 271 190 332 120 177 268 169 179 160
#  140 175 567 500 132 563 453 170 115 158 260 187 381 631 543 604 620 317
#  108 372 122 197 333 225 550 380 357 560 138 110 283 263 234 272 269 323
#  426 188 312 228 230 145 148 156 173 420 525 430 385 429 274 166 194 290
#  368 210 306 451 412 444 142 315 244 276 191 304 176 113 266 285 354 435
#  505 251 198 249 117 165 161 262 355 273 382 510 518 536 507 162 556 152
#  297 320 638 403 291 275 292 335 171 136 107 180 261 360 503 400 109 100
#  167 153 239 303 390 172 379 470 425 330 182 370 288 232 212 218 106 264
#  224 345 408 242 328 535 455 348 352 414 135 201 255 405 155 252 248 150
#  342 220 375 540 186 121 181 208 118 363 178 189 217 257 164 433 440 202
#  205 215 256 204 159 236 128 490 143 207 416 383 365 411 465 376 318 308]
# Engine Information.Engine Statistics.Torque [236 207 243 325 266 258 254 273 500 190 334 295 373 260 305 276 774 590
#  479 553 170 354 278 178 251 162 270 112 161 248 167 171 146 136 180 516
#  738 128 575 531 177 125 271 310 186 401 664 385 105 265 328 127 139 406
#  398 367 344 123 106 233 263 257 226 172 246 420 221 200 300 130 131 133
#  223 249 228 144 168 317 391 316 333 291 376 269 154 169 184 107 264 324
#  443 280 390 380 115 137 240 510 253 181 109 288 388 250 470 424 230 259
#  179 163 229 350 612 465 262 255 157 551 327 332 604 147 400 417 145 215
#  425 339 148 111 166 281 360 245 450 267  98 135 315 365 287 369 272 141
#  165 268 410 336 182 395 140 159 187 103 222 175 480 235 389 242 320 205
#  550 330 232 515 335 382 393 413 142 214 560 427 150 216 174 217 213 274
#  237 244 290 234 375 461 434 191 173 114 192 160 394 155 156 158 361 247
#  275 383 225 407 220 346 185 277 238 338 371 403 286 329 294 463 343 502
#  752]

# %% [markdown]
# From this we can see some points for improvement.
#
# - All wheel drive and four wheel drive are the same thing.
# - Variables contain more than one piece of information. For example Engine Information.Engine Type contains the make, the number of litres, number of cylinders, horsepower, torque and turbo. It'd be ideal to split these into their own variables.
# - There seems to be an error with the hybrid feature as all cars are claimed to be hybrid which is clearly not the case.

# %% [markdown]
# Replace four wheel drive with all wheel drive

# %%
df.replace("Four-wheel drive","All-wheel drive", inplace=True)

# %%
df[df["Engine Information.Driveline"] == "Four-wheel drive"]
# Out:
# Empty DataFrame
# Columns: [Dimensions.Height, Dimensions.Length, Dimensions.Width, Engine Information.Driveline, Engine Information.Engine Type, Engine Information.Hybrid, Engine Information.Number of Forward Gears, Engine Information.Transmission, Fuel Information.City mpg, Fuel Information.Fuel Type, Fuel Information.Highway mpg, Identification.Classification, Identification.ID, Identification.Make, Identification.Model Year, Identification.Year, Engine Information.Engine Statistics.Horsepower, Engine Information.Engine Statistics.Torque]
# Index: []

# %% [markdown]
# Drop hybrid feature.

# %%
df.drop("Engine Information.Hybrid", axis = 1, inplace=True)

df
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 5                    91                 17                62
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 1               Front-wheel drive
# 2               Front-wheel drive
# 3                 All-wheel drive
# 5                 All-wheel drive
# ...                           ...
# 5071            Front-wheel drive
# 5072              All-wheel drive
# 5073              All-wheel drive
# 5074             Rear-wheel drive
# 5075             Rear-wheel drive
#
#                       Engine Information.Engine Type  \
# 0               Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 5              Audi 3.2L 6 cylinder 265hp 243 ft-lbs
# ...                                              ...
# 5071         Honda 3.5L 6 Cylinder 250 hp 253 ft-lbs
# 5072  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs
# 5073  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs
# 5074      BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo
# 5075      BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo
#
#       Engine Information.Number of Forward Gears  \
# 0                                              6
# 1                                              6
# 2                                              6
# 3                                              6
# 5                                              6
# ...                                          ...
# 5071                                           5
# 5072                                           6
# 5073                                           6
# 5074                                           6
# 5075                                           6
#
#      Engine Information.Transmission  Fuel Information.City mpg  \
# 0     6 Speed Automatic Select Shift                         18
# 1     6 Speed Automatic Select Shift                         22
# 2                     6 Speed Manual                         21
# 3     6 Speed Automatic Select Shift                         21
# 5                     6 Speed Manual                         16
# ...                              ...                        ...
# 5071               5 Speed Automatic                         18
# 5072                  6 Speed Manual                         12
# 5073                  6 Speed Manual                         12
# 5074  6 Speed Automatic Select Shift                         17
# 5075  6 Speed Automatic Select Shift                         17
#
#      Fuel Information.Fuel Type  Fuel Information.Highway mpg  \
# 0                      Gasoline                            25
# 1                      Gasoline                            28
# 2                      Gasoline                            30
# 3                      Gasoline                            28
# 5                      Gasoline                            27
# ...                         ...                           ...
# 5071                   Gasoline                            25
# 5072                   Gasoline                            20
# 5073                   Gasoline                            20
# 5074                   Gasoline                            25
# 5075                   Gasoline                            25
#
#      Identification.Classification                          Identification.ID  \
# 0           Automatic transmission                           2009 Audi A3 3.2
# 1           Automatic transmission                      2009 Audi A3 2.0 T AT
# 2              Manual transmission                         2009 Audi A3 2.0 T
# 3           Automatic transmission                 2009 Audi A3 2.0 T Quattro
# 5              Manual transmission                           2009 Audi A5 3.2
# ...                            ...                                        ...
# 5071        Automatic transmission                      2012 Honda Pilot EX-L
# 5072           Manual transmission   2012 Lamborghini Gallardo Coupe LP 560-4
# 5073           Manual transmission  2012 Lamborghini Gallardo LP 560-4 Spyder
# 5074        Automatic transmission                        2012 BMW 740i Sedan
# 5075        Automatic transmission                       2012 BMW 740Li Sedan
#
#      Identification.Make         Identification.Model Year  \
# 0                   Audi                      2009 Audi A3
# 1                   Audi                      2009 Audi A3
# 2                   Audi                      2009 Audi A3
# 3                   Audi                      2009 Audi A3
# 5                   Audi                      2009 Audi A5
# ...                  ...                               ...
# 5071               Honda                  2012 Honda Pilot
# 5072         Lamborghini    2012 Lamborghini Gallardo Coup
# 5073         Lamborghini  2012 Lamborghini Gallardo Spyder
# 5074                 BMW                 2012 BMW 7 Series
# 5075                 BMW                 2012 BMW 7 Series
#
#       Identification.Year  Engine Information.Engine Statistics.Horsepower  \
# 0                    2009                                              250
# 1                    2009                                              200
# 2                    2009                                              200
# 3                    2009                                              200
# 5                    2009                                              265
# ...                   ...                                              ...
# 5071                 2012                                              250
# 5072                 2012                                              552
# 5073                 2012                                              552
# 5074                 2012                                              315
# 5075                 2012                                              315
#
#       Engine Information.Engine Statistics.Torque
# 0                                             236
# 1                                             207
# 2                                             207
# 3                                             207
# 5                                             243
# ...                                           ...
# 5071                                          253
# 5072                                          398
# 5073                                          398
# 5074                                          330
# 5075                                          330
#
# [5030 rows x 17 columns]

# %% [markdown]
# Split Engine Information.Engine Type into its various entities

# %%
df_copy = df.copy(deep=True)
split_columns = df_copy["Engine Information.Engine Type"].str.split(" ", expand=True)

capacity = split_columns[1]
df_copy["engine_make"] = split_columns[0].where(capacity.str[-1].str.upper() == "L", split_columns[0] + " " + capacity)
df_copy["engine_capacity"] = capacity.str[:-1].where(capacity.str[-1].str.upper() == "L", split_columns[2].str[:-1])
df_copy["engine_cylinders"] = split_columns[2].where(capacity.str[-1].str.upper() == "L", split_columns[3])
df_copy["engine_modifier"] = split_columns[8].where(capacity.str[-1].str.upper() == "L", split_columns[9])

# Fill empty cylinders with 6 (Cadillac quirk)
df_copy["engine_cylinders"].replace("", "6", inplace=True)

# Fill empty capacities (Volvo quirk)
mask = df_copy["engine_capacity"] == ""
df_copy.loc[mask, "engine_capacity"] = df_copy.loc[mask, "engine_make"].str.split(" ", expand=True)[1]

# Fix Volvo engine make
df_copy.loc[mask, "engine_make"] = df_copy.loc[mask, "engine_make"].str.split(" ", expand=True)[0]

# Replace 2010 Volkswagen Touareg V6 TDI Clean Diesel Sport cylinders
df_copy["engine_cylinders"].replace("225", "6", inplace=True)

# Replace RX-8 cylinders
df_copy["engine_cylinders"].replace("R2", "4", inplace=True)

# Replace Aston Martin 6.0L 510 hp 420 ft-lbs cylinders
df_copy["engine_cylinders"].replace("510", "12", inplace=True)

# Replace 2012 Lexus LFA cylinders
df_copy["engine_cylinders"].replace("552", "10", inplace=True)

# Drop old column.
df_copy.drop("Engine Information.Engine Type", axis=1, inplace=True)
df_copy
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 5                    91                 17                62
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  Engine Information.Number of Forward Gears  \
# 0                 All-wheel drive                                           6
# 1               Front-wheel drive                                           6
# 2               Front-wheel drive                                           6
# 3                 All-wheel drive                                           6
# 5                 All-wheel drive                                           6
# ...                           ...                                         ...
# 5071            Front-wheel drive                                           5
# 5072              All-wheel drive                                           6
# 5073              All-wheel drive                                           6
# 5074             Rear-wheel drive                                           6
# 5075             Rear-wheel drive                                           6
#
#      Engine Information.Transmission  Fuel Information.City mpg  \
# 0     6 Speed Automatic Select Shift                         18
# 1     6 Speed Automatic Select Shift                         22
# 2                     6 Speed Manual                         21
# 3     6 Speed Automatic Select Shift                         21
# 5                     6 Speed Manual                         16
# ...                              ...                        ...
# 5071               5 Speed Automatic                         18
# 5072                  6 Speed Manual                         12
# 5073                  6 Speed Manual                         12
# 5074  6 Speed Automatic Select Shift                         17
# 5075  6 Speed Automatic Select Shift                         17
#
#      Fuel Information.Fuel Type  Fuel Information.Highway mpg  \
# 0                      Gasoline                            25
# 1                      Gasoline                            28
# 2                      Gasoline                            30
# 3                      Gasoline                            28
# 5                      Gasoline                            27
# ...                         ...                           ...
# 5071                   Gasoline                            25
# 5072                   Gasoline                            20
# 5073                   Gasoline                            20
# 5074                   Gasoline                            25
# 5075                   Gasoline                            25
#
#      Identification.Classification                          Identification.ID  \
# 0           Automatic transmission                           2009 Audi A3 3.2
# 1           Automatic transmission                      2009 Audi A3 2.0 T AT
# 2              Manual transmission                         2009 Audi A3 2.0 T
# 3           Automatic transmission                 2009 Audi A3 2.0 T Quattro
# 5              Manual transmission                           2009 Audi A5 3.2
# ...                            ...                                        ...
# 5071        Automatic transmission                      2012 Honda Pilot EX-L
# 5072           Manual transmission   2012 Lamborghini Gallardo Coupe LP 560-4
# 5073           Manual transmission  2012 Lamborghini Gallardo LP 560-4 Spyder
# 5074        Automatic transmission                        2012 BMW 740i Sedan
# 5075        Automatic transmission                       2012 BMW 740Li Sedan
#
#      Identification.Make         Identification.Model Year  \
# 0                   Audi                      2009 Audi A3
# 1                   Audi                      2009 Audi A3
# 2                   Audi                      2009 Audi A3
# 3                   Audi                      2009 Audi A3
# 5                   Audi                      2009 Audi A5
# ...                  ...                               ...
# 5071               Honda                  2012 Honda Pilot
# 5072         Lamborghini    2012 Lamborghini Gallardo Coup
# 5073         Lamborghini  2012 Lamborghini Gallardo Spyder
# 5074                 BMW                 2012 BMW 7 Series
# 5075                 BMW                 2012 BMW 7 Series
#
#       Identification.Year  Engine Information.Engine Statistics.Horsepower  \
# 0                    2009                                              250
# 1                    2009                                              200
# 2                    2009                                              200
# 3                    2009                                              200
# 5                    2009                                              265
# ...                   ...                                              ...
# 5071                 2012                                              250
# 5072                 2012                                              552
# 5073                 2012                                              552
# 5074                 2012                                              315
# 5075                 2012                                              315
#
#       Engine Information.Engine Statistics.Torque  engine_make  \
# 0                                             236         Audi
# 1                                             207         Audi
# 2                                             207         Audi
# 3                                             207         Audi
# 5                                             243         Audi
# ...                                           ...          ...
# 5071                                          253        Honda
# 5072                                          398  Lamborghini
# 5073                                          398  Lamborghini
# 5074                                          330          BMW
# 5075                                          330          BMW
#
#      engine_capacity engine_cylinders engine_modifier
# 0                3.2                6            None
# 1                2.0                4           Turbo
# 2                2.0                4           Turbo
# 3                2.0                4           Turbo
# 5                3.2                6            None
# ...              ...              ...             ...
# 5071             3.5                6            None
# 5072             5.2               10            None
# 5073             5.2               10            None
# 5074             3.0                6            None
# 5075             3.0                6            None
#
# [5030 rows x 20 columns]

# %% [markdown]
# Remove year from Identification.Model Year since year is already in Identification.Year

# %%
model_year = df_copy["Identification.Model Year"].str.split(" ")
model_year = model_year.apply(lambda x: x[1:])

df_copy["Identification.Model Year"] = model_year.apply(lambda x: " ".join(x))
df_copy
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 5                    91                 17                62
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  Engine Information.Number of Forward Gears  \
# 0                 All-wheel drive                                           6
# 1               Front-wheel drive                                           6
# 2               Front-wheel drive                                           6
# 3                 All-wheel drive                                           6
# 5                 All-wheel drive                                           6
# ...                           ...                                         ...
# 5071            Front-wheel drive                                           5
# 5072              All-wheel drive                                           6
# 5073              All-wheel drive                                           6
# 5074             Rear-wheel drive                                           6
# 5075             Rear-wheel drive                                           6
#
#      Engine Information.Transmission  Fuel Information.City mpg  \
# 0     6 Speed Automatic Select Shift                         18
# 1     6 Speed Automatic Select Shift                         22
# 2                     6 Speed Manual                         21
# 3     6 Speed Automatic Select Shift                         21
# 5                     6 Speed Manual                         16
# ...                              ...                        ...
# 5071               5 Speed Automatic                         18
# 5072                  6 Speed Manual                         12
# 5073                  6 Speed Manual                         12
# 5074  6 Speed Automatic Select Shift                         17
# 5075  6 Speed Automatic Select Shift                         17
#
#      Fuel Information.Fuel Type  Fuel Information.Highway mpg  \
# 0                      Gasoline                            25
# 1                      Gasoline                            28
# 2                      Gasoline                            30
# 3                      Gasoline                            28
# 5                      Gasoline                            27
# ...                         ...                           ...
# 5071                   Gasoline                            25
# 5072                   Gasoline                            20
# 5073                   Gasoline                            20
# 5074                   Gasoline                            25
# 5075                   Gasoline                            25
#
#      Identification.Classification                          Identification.ID  \
# 0           Automatic transmission                           2009 Audi A3 3.2
# 1           Automatic transmission                      2009 Audi A3 2.0 T AT
# 2              Manual transmission                         2009 Audi A3 2.0 T
# 3           Automatic transmission                 2009 Audi A3 2.0 T Quattro
# 5              Manual transmission                           2009 Audi A5 3.2
# ...                            ...                                        ...
# 5071        Automatic transmission                      2012 Honda Pilot EX-L
# 5072           Manual transmission   2012 Lamborghini Gallardo Coupe LP 560-4
# 5073           Manual transmission  2012 Lamborghini Gallardo LP 560-4 Spyder
# 5074        Automatic transmission                        2012 BMW 740i Sedan
# 5075        Automatic transmission                       2012 BMW 740Li Sedan
#
#      Identification.Make    Identification.Model Year  Identification.Year  \
# 0                   Audi                      Audi A3                 2009
# 1                   Audi                      Audi A3                 2009
# 2                   Audi                      Audi A3                 2009
# 3                   Audi                      Audi A3                 2009
# 5                   Audi                      Audi A5                 2009
# ...                  ...                          ...                  ...
# 5071               Honda                  Honda Pilot                 2012
# 5072         Lamborghini    Lamborghini Gallardo Coup                 2012
# 5073         Lamborghini  Lamborghini Gallardo Spyder                 2012
# 5074                 BMW                 BMW 7 Series                 2012
# 5075                 BMW                 BMW 7 Series                 2012
#
#       Engine Information.Engine Statistics.Horsepower  \
# 0                                                 250
# 1                                                 200
# 2                                                 200
# 3                                                 200
# 5                                                 265
# ...                                               ...
# 5071                                              250
# 5072                                              552
# 5073                                              552
# 5074                                              315
# 5075                                              315
#
#       Engine Information.Engine Statistics.Torque  engine_make  \
# 0                                             236         Audi
# 1                                             207         Audi
# 2                                             207         Audi
# 3                                             207         Audi
# 5                                             243         Audi
# ...                                           ...          ...
# 5071                                          253        Honda
# 5072                                          398  Lamborghini
# 5073                                          398  Lamborghini
# 5074                                          330          BMW
# 5075                                          330          BMW
#
#      engine_capacity engine_cylinders engine_modifier
# 0                3.2                6            None
# 1                2.0                4           Turbo
# 2                2.0                4           Turbo
# 3                2.0                4           Turbo
# 5                3.2                6            None
# ...              ...              ...             ...
# 5071             3.5                6            None
# 5072             5.2               10            None
# 5073             5.2               10            None
# 5074             3.0                6            None
# 5075             3.0                6            None
#
# [5030 rows x 20 columns]

# %% [markdown]
# Drop Engine Information.Transmission since useful information is already in Identification.Classification.

# %%
df_copy.drop("Engine Information.Transmission", axis=1, inplace=True)
df_copy
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 5                    91                 17                62
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  Engine Information.Number of Forward Gears  \
# 0                 All-wheel drive                                           6
# 1               Front-wheel drive                                           6
# 2               Front-wheel drive                                           6
# 3                 All-wheel drive                                           6
# 5                 All-wheel drive                                           6
# ...                           ...                                         ...
# 5071            Front-wheel drive                                           5
# 5072              All-wheel drive                                           6
# 5073              All-wheel drive                                           6
# 5074             Rear-wheel drive                                           6
# 5075             Rear-wheel drive                                           6
#
#       Fuel Information.City mpg Fuel Information.Fuel Type  \
# 0                            18                   Gasoline
# 1                            22                   Gasoline
# 2                            21                   Gasoline
# 3                            21                   Gasoline
# 5                            16                   Gasoline
# ...                         ...                        ...
# 5071                         18                   Gasoline
# 5072                         12                   Gasoline
# 5073                         12                   Gasoline
# 5074                         17                   Gasoline
# 5075                         17                   Gasoline
#
#       Fuel Information.Highway mpg Identification.Classification  \
# 0                               25        Automatic transmission
# 1                               28        Automatic transmission
# 2                               30           Manual transmission
# 3                               28        Automatic transmission
# 5                               27           Manual transmission
# ...                            ...                           ...
# 5071                            25        Automatic transmission
# 5072                            20           Manual transmission
# 5073                            20           Manual transmission
# 5074                            25        Automatic transmission
# 5075                            25        Automatic transmission
#
#                               Identification.ID Identification.Make  \
# 0                              2009 Audi A3 3.2                Audi
# 1                         2009 Audi A3 2.0 T AT                Audi
# 2                            2009 Audi A3 2.0 T                Audi
# 3                    2009 Audi A3 2.0 T Quattro                Audi
# 5                              2009 Audi A5 3.2                Audi
# ...                                         ...                 ...
# 5071                      2012 Honda Pilot EX-L               Honda
# 5072   2012 Lamborghini Gallardo Coupe LP 560-4         Lamborghini
# 5073  2012 Lamborghini Gallardo LP 560-4 Spyder         Lamborghini
# 5074                        2012 BMW 740i Sedan                 BMW
# 5075                       2012 BMW 740Li Sedan                 BMW
#
#         Identification.Model Year  Identification.Year  \
# 0                         Audi A3                 2009
# 1                         Audi A3                 2009
# 2                         Audi A3                 2009
# 3                         Audi A3                 2009
# 5                         Audi A5                 2009
# ...                           ...                  ...
# 5071                  Honda Pilot                 2012
# 5072    Lamborghini Gallardo Coup                 2012
# 5073  Lamborghini Gallardo Spyder                 2012
# 5074                 BMW 7 Series                 2012
# 5075                 BMW 7 Series                 2012
#
#       Engine Information.Engine Statistics.Horsepower  \
# 0                                                 250
# 1                                                 200
# 2                                                 200
# 3                                                 200
# 5                                                 265
# ...                                               ...
# 5071                                              250
# 5072                                              552
# 5073                                              552
# 5074                                              315
# 5075                                              315
#
#       Engine Information.Engine Statistics.Torque  engine_make  \
# 0                                             236         Audi
# 1                                             207         Audi
# 2                                             207         Audi
# 3                                             207         Audi
# 5                                             243         Audi
# ...                                           ...          ...
# 5071                                          253        Honda
# 5072                                          398  Lamborghini
# 5073                                          398  Lamborghini
# 5074                                          330          BMW
# 5075                                          330          BMW
#
#      engine_capacity engine_cylinders engine_modifier
# 0                3.2                6            None
# 1                2.0                4           Turbo
# 2                2.0                4           Turbo
# 3                2.0                4           Turbo
# 5                3.2                6            None
# ...              ...              ...             ...
# 5071             3.5                6            None
# 5072             5.2               10            None
# 5073             5.2               10            None
# 5074             3.0                6            None
# 5075             3.0                6            None
#
# [5030 rows x 19 columns]

# %% [markdown]
# Rename columns for uniform naming standard.

# %%
df_copy.rename(columns={"Dimensions.Height": "height"}, inplace=True)
df_copy.rename(columns={"Dimensions.Length": "length"}, inplace=True)
df_copy.rename(columns={"Dimensions.Width": "width"}, inplace=True)
df_copy.rename(columns={"Engine Information.Driveline": "driveline"}, inplace=True)
df_copy.rename(columns={"Engine Information.Number of Forward Gears": "num_gears"}, inplace=True)
df_copy.rename(columns={"Fuel Information.City mpg": "city_mpg"}, inplace=True)
df_copy.rename(columns={"Fuel Information.Highway mpg": "highway_mpg"}, inplace=True)
df_copy.rename(columns={"Fuel Information.Fuel Type": "fuel_type"}, inplace=True)
df_copy.rename(columns={"Identification.Classification": "transmission"}, inplace=True)
df_copy.rename(columns={"Identification.ID": "id"}, inplace=True)
df_copy.rename(columns={"Identification.Make": "make"}, inplace=True)
df_copy.rename(columns={"Identification.Model Year": "model"}, inplace=True)
df_copy.rename(columns={"Identification.Year": "year"}, inplace=True)
df_copy.rename(columns={"Engine Information.Engine Statistics.Horsepower": "horsepower"}, inplace=True)
df_copy.rename(columns={"Engine Information.Engine Statistics.Torque": "torque"}, inplace=True)

df_copy
# Out:
#       height  length  width          driveline  num_gears  city_mpg fuel_type  \
# 0        140     143    202    All-wheel drive          6        18  Gasoline
# 1        140     143    202  Front-wheel drive          6        22  Gasoline
# 2        140     143    202  Front-wheel drive          6        21  Gasoline
# 3        140     143    202    All-wheel drive          6        21  Gasoline
# 5         91      17     62    All-wheel drive          6        16  Gasoline
# ...      ...     ...    ...                ...        ...       ...       ...
# 5071      13     253    201  Front-wheel drive          5        18  Gasoline
# 5072     141     249    108    All-wheel drive          6        12  Gasoline
# 5073     160     249    108    All-wheel drive          6        12  Gasoline
# 5074     200     210    110   Rear-wheel drive          6        17  Gasoline
# 5075     200      94    110   Rear-wheel drive          6        17  Gasoline
#
#       highway_mpg            transmission  \
# 0              25  Automatic transmission
# 1              28  Automatic transmission
# 2              30     Manual transmission
# 3              28  Automatic transmission
# 5              27     Manual transmission
# ...           ...                     ...
# 5071           25  Automatic transmission
# 5072           20     Manual transmission
# 5073           20     Manual transmission
# 5074           25  Automatic transmission
# 5075           25  Automatic transmission
#
#                                              id         make  \
# 0                              2009 Audi A3 3.2         Audi
# 1                         2009 Audi A3 2.0 T AT         Audi
# 2                            2009 Audi A3 2.0 T         Audi
# 3                    2009 Audi A3 2.0 T Quattro         Audi
# 5                              2009 Audi A5 3.2         Audi
# ...                                         ...          ...
# 5071                      2012 Honda Pilot EX-L        Honda
# 5072   2012 Lamborghini Gallardo Coupe LP 560-4  Lamborghini
# 5073  2012 Lamborghini Gallardo LP 560-4 Spyder  Lamborghini
# 5074                        2012 BMW 740i Sedan          BMW
# 5075                       2012 BMW 740Li Sedan          BMW
#
#                             model  year  horsepower  torque  engine_make  \
# 0                         Audi A3  2009         250     236         Audi
# 1                         Audi A3  2009         200     207         Audi
# 2                         Audi A3  2009         200     207         Audi
# 3                         Audi A3  2009         200     207         Audi
# 5                         Audi A5  2009         265     243         Audi
# ...                           ...   ...         ...     ...          ...
# 5071                  Honda Pilot  2012         250     253        Honda
# 5072    Lamborghini Gallardo Coup  2012         552     398  Lamborghini
# 5073  Lamborghini Gallardo Spyder  2012         552     398  Lamborghini
# 5074                 BMW 7 Series  2012         315     330          BMW
# 5075                 BMW 7 Series  2012         315     330          BMW
#
#      engine_capacity engine_cylinders engine_modifier
# 0                3.2                6            None
# 1                2.0                4           Turbo
# 2                2.0                4           Turbo
# 3                2.0                4           Turbo
# 5                3.2                6            None
# ...              ...              ...             ...
# 5071             3.5                6            None
# 5072             5.2               10            None
# 5073             5.2               10            None
# 5074             3.0                6            None
# 5075             3.0                6            None
#
# [5030 rows x 19 columns]

# %% [markdown]
# Re-run key commands.

# %%
df_copy.dtypes
# Out:
# height                 int64
# length                 int64
# width                  int64
# driveline           category
# num_gears              int64
# city_mpg               int64
# fuel_type           category
# highway_mpg            int64
# transmission        category
# id                    object
# make                  object
# model                 object
# year                   int64
# horsepower             int64
# torque                 int64
# Categories (4, object): ['Compressed natural gas', 'Diesel fuel', 'E85', 'Gasoline']
# highway_mpg [ 25  28  30  27  26  18  20  29  17  12  13  19  15  14  22  24  31  21
#   23  38  37  32  33  36  35  34  41  16  42  40  39 223  11  43]
# transmission ['Automatic transmission', 'Manual transmission']
# Categories (2, object): ['Automatic transmission', 'Manual transmission']
# id ['2009 Audi A3 3.2' '2009 Audi A3 2.0 T AT' '2009 Audi A3 2.0 T' ...
#  '2012 Lamborghini Gallardo LP 560-4 Spyder' '2012 BMW 740i Sedan'
#  '2012 BMW 740Li Sedan']
# make ['Audi' 'Acura' 'BMW' 'Chevrolet' 'Nissan' 'Volvo' 'Bentley' 'Toyota'
#  'Honda' 'Ford' 'Rolls-Royce' 'Volkswagen' 'Maybach' 'Lamborghini' 'Lexus'
#  'Hyundai' 'Mercedes' 'BMW Motorrad' 'Kia' 'AMG' 'Mazda' 'Mercedes-Benz'
#  'Mercedes-AMG' 'Mitsubishi' 'Cadillac' 'Infiniti' 'Dodge' 'Lincoln' 'GMC'
#  'Porsche' 'Jeep' 'Subaru' 'Buick' 'Suzuki' 'Saab' 'Aston Martin'
#  'Grand Cherokee' 'Land Rover' 'Chrysler' 'Ferrari' 'Scion' 'MINI'
#  'Jaguar' 'Chrysler Group LLC' 'Lotus' 'Maserati' 'Mercury']
# model ['Audi A3' 'Audi A5' 'Audi Q7' 'Audi A4 Sedan' 'Acura TL' 'BMW X5'
#  'BMW X6' 'Chevrolet Colorado' 'Chevrolet Express'
#  'Chevrolet Silverado 1500' 'Nissan 370Z Coupe' 'Volvo C30'
#  'Bentley Brooklands' 'Bentley Continental Supersports Convertible'
#  'Bentley Continental Supersports Coupe' 'Bentley Continental Supersports'
#  'Bentley Continental Flying Spur' 'Volvo C70' 'Volvo S40' 'Volvo S60'
#  'Volvo S80' 'Volvo V50' 'Volvo XC60' 'Volvo XC70' 'Toyota 4Runner'
#  'Volvo XC90' 'Volvo V70' 'Honda Accord Coupe' 'Nissan 370Z Roadster'
#  'Ford Fiesta Sedan' 'Audi A4 Avant' 'Honda Accord Coup'
#  'Ford Fiesta Hatchback' 'Honda Accord Sedan' 'Toyota Avalon'
#  'Toyota Camry' 'Ford Focus Sedan' 'Nissan Altima Coupe'
#  'Bentley Continental GT' 'Ford Focus Coupe' 'Bentley Continental GTC'
#  'Bentley Azure T' 'Toyota Corolla' 'Rolls-Royce Ghost'
#  'Audi A5 Cabriolet' 'Rolls-Royce Phantom Sedan' 'Audi A5 Coupe'
#  'Rolls-Royce Phantom Coupe' 'Rolls-Royce Phantom Drophead Coupe'
#  'Volkswagen Jetta' 'Toyota FJ Cruiser' 'Audi A6 Sedan'
#  'Toyota Highlander' 'Honda Accord Crosstour Hatchback'
#  'Toyota Land Cruiser' 'Toyota Matrix' 'Maybach 57' 'Maybach 62'
#  'Maybach Landaulet' 'Nissan Armada' 'Volkswagen Jetta SportWagen'
#  'Chevrolet Aveo' 'Volkswagen CC' 'Chevrolet Aveo5' 'Audi A6 Avant'
#  'Audi A7' 'Audi A8' 'Nissan Cube' 'Audi Q5' 'Honda Civic Coup'
#  'Lamborghini Gallardo Coupe' 'Lexus LS' 'Hyundai Accent Hatchback'
#  'Hyundai Accent Sedan' 'Hyundai Azera' 'Toyota RAV4'
#  'Chevrolet Camaro Convertible' 'Nissan Juke' 'Mercedes-Benz C-Class'
#  'BMW 1 Series Convertible' 'Chevrolet Camaro Coupe'
#  'Hyundai Elantra Sedan' 'Ford Fusion' 'Kia Forte' 'Kia Forte 5-Door'
#  'Kia Forte Koup' 'Audi R8 Coupe' 'Hyundai Elantra Touring'
#  'Hyundai Equus' 'Hyundai Genesis Sedan' 'Kia Optima' 'Kia Optima Hybrid'
#  'Kia Rio' 'Hyundai Genesis Coupe' 'Volkswagen GTI 2-Door'
#  'Ford Mustang Coup' 'Ford Mustang Convertible' 'Kia Rio5'
#  'Volkswagen GTI 4-Door' 'Kia Soul' 'Kia Sedona'
#  'Ford Mustang Shelby GT500 Convertible' 'Ford Mustang Shelby GT500 Coupe'
#  'Ford Shelby GT500 Coupe' 'Audi R8 Spyder' 'Kia Sorento' 'Audi S4 Sedan'
#  'Kia Sportage' 'Volkswagen Golf 2-Door' 'Honda Civic Sedan'
#  'Nissan Pathfinder' 'Hyundai Santa Fe' 'Ford Taurus'
#  'Volkswagen Golf 4-Door' 'Ford Edge' 'Audi S5 Coupe' 'Audi S6'
#  'Chevrolet Corvette Z06' 'Chevrolet Corvette Convertible'
#  ' Volkswagen Routan' 'Volkswagen Routan' 'Volkswagen Tiguan'
#  'Hyundai Sonata' 'Honda CR-Z' 'Hyundai Veracruz' 'Honda Fit'
#  'Hyundai Sonata Hybrid' 'Hyundai Tucson' 'Mazda CX-7' 'Ford Flex'
#  'Mazda CX-9' 'Volkswagen Touareg' 'Mercedes-Benz CL-Class'
#  'BMW 1 Series Coupe' 'Mercedes-Benz CLS-Class' 'Mitsubishi Eclipse Coupe'
#  'Chevrolet Corvette Coupe' 'Mitsubishi Eclipse Spyder'
#  'Mitsubishi Endeavor' 'Mitsubishi Galant' 'Cadillac CTS-V Sedan'
#  'Mitsubishi Lancer' 'Cadillac CTS-V Coupe' 'Cadillac CTS-V Wagon'
#  'Cadillac CTS Sport Sedan' 'Toyota Sequoia' 'BMW 3 Series Convertible'
#  'Infiniti EX' 'Mercedes-Benz E-Class Cabriolet'
#  'Mercedes-Benz E-Class Coupe' 'Mercedes-Benz E-Class Sedan'
#  'BMW 3 Series Coup' 'Chevrolet Corvette ZR1' 'Nissan Sentra'
#  'Chevrolet Corvette Grand Sport Coupe' 'Mercedes-Benz E-Class Wagon'
#  'Mercedes-Benz G-Class' 'Chevrolet Corvette Grand Sport Convertible'
#  'Cadillac Escalade ESV' 'Mitsubishi Lancer Evolution'
#  'Mitsubishi Lancer Sportback' 'Mitsubishi Outlander' 'Cadillac CTS Coupe'
#  'Mitsubishi Outlander Sport' 'Cadillac DTS' 'BMW 3 Series Sedan'
#  'Mercedes-Benz GL-Class' 'Nissan Versa Hatchback'
#  'Mercedes-Benz GLK-Class' 'Ford Escape' 'Mercedes-Benz R-Class'
#  'Chevrolet Cruze' 'BMW 3 Series Sports Wagon' 'Cadillac SRX'
#  'Nissan Versa Sedan' 'Cadillac Escalade Hybrid' 'Dodge Avenger'
#  'Honda CR-V' 'Honda Element' 'Cadillac Escalade' 'Nissan Xterra'
#  'BMW 5 Series Sedan' 'Mercedes-Benz M-Class' 'Toyota Sienna'
#  'Mercedes-Benz SL-Class' 'Mercedes-Benz SLK-Class' 'Lincoln MKS'
#  'BMW 5 Series Sports Wagon' 'Lincoln MKT' 'Lincoln MKX'
#  'Lincoln MKZ Sedan' 'Mazda Mazda2' 'Mazda Mazda3 4-Door'
#  'Mazda Mazda3 5-Door' 'Ford Explorer' 'Mazda Mazdaspeed3' 'Mazda Mazda5'
#  'Honda Pilot' 'Mazda Mazda6' 'Cadillac CTS Sport Wagon'
#  'Lincoln Navigator' 'Lincoln Town Car' 'BMW 5 Series Gran Turismo'
#  'Infiniti FX' 'Infiniti M Hybrid' 'Cadillac STS' 'Infiniti M'
#  'Dodge Caliber' 'Dodge Challenger' 'BMW 6 Series Convertible'
#  'Toyota Venza' 'Ford Expedition' 'Dodge Charger' 'GMC Acadia'
#  'Dodge Durango' 'Mazda MX-5 Miata' 'Mazda RX-8' 'Infiniti G25'
#  'Toyota Yaris 5-Door Liftback' 'Chevrolet Equinox'
#  'Toyota Yaris 3-Door Liftback' 'Toyota Yaris Sedan'
#  'Ford Transit Connect Van' 'Ford Transit Connect Wagon'
#  'Transit Connect Van' 'Transit Connect Wagon' 'Ford Crown Victoria'
#  'Porsche 911 Coupe' 'Infiniti G37 Convertible' 'Mazda Tribute'
#  'Porsche 911 Cabriolet' 'Dodge Grand Caravan' 'Jeep Commander'
#  'Jeep Compass' 'GMC Canyon' 'GMC Terrain' 'Dodge Journey'
#  'Infiniti G37 Sedan' 'BMW 6 Series Coup' 'BMW 7 Series'
#  'BMW ActiveHybrid 7 Sedan' 'Dodge Nitro' 'BMW ALPINA B7 Sedan' 'Lexus ES'
#  'Infiniti G37 Coupe' 'Infiniti IPL G Coupe' 'GMC Yukon' 'GMC Yukon XL'
#  'Infiniti QX56' 'Acura MDX' 'Acura RDX' 'BMW M3 Convertible' 'Acura ZDX'
#  'Acura RL' 'BMW M3 Coup' 'BMW M3 Sedan' 'Acura TSX'
#  'Acura TSX Sport Wagon' 'GMC Yukon Hybrid' 'GMC Savana' 'Porsche Boxster'
#  'Dodge Viper Coup' 'Dodge Viper Convertible' 'Porsche Cayenne S Hybrid'
#  'Porsche Cayenne' 'Chevrolet HHR Wagon' 'Chevrolet HHR Panel'
#  'Porsche Cayman' 'Chevrolet Impala' 'Subaru Forester' 'Buick Enclave'
#  'Suzuki Grand Vitara' 'Buick Lacrosse' 'Honda Odyssey' 'GMC Sierra 1500'
#  'Suzuki Kizashi' 'Saab 9-3 Convertible' 'Suzuki SX4 Sedan'
#  'Suzuki SX4 Sportback' 'Saab 9-3 Sport Sedan' 'Lexus GS'
#  'Subaru Impreza Sedan' 'Buick Lucerne' 'Buick Regal'
#  'Aston Martin DB9 Volante' 'Jeep Grand Cherokee'
#  'Subaru Impreza WRX Sedan' 'Jeep Liberty' 'Land Rover LR2'
#  'Land Rover LR4' 'Land Rover Range Rover' 'Land Rover Range Rover Evoque'
#  'Chrysler 200 Convertible' 'Ferrari 612 Scaglietti'
#  'Land Rover Range Rover Sport' 'Chrysler Sebring Convertible'
#  'Chrysler Sebring Sedan' 'Saab 9-3 SportCombi' 'Scion tC'
#  'Aston Martin DB9 Coup' 'MINI Cooper Hardtop' 'MINI Cooper Convertible'
#  'Jaguar XJ' 'Chevrolet Malibu' 'MINI Clubman' 'Aston Martin DBS Volante'
#  'Aston Martin Rapide' 'Chrysler 200 Sedan' 'Jaguar XK Convertible'
#  'Jaguar XK Coup' 'Chrysler 300' 'Jaguar XF' 'Jeep Patriot'
#  'Chrysler Town and Country' 'Lotus Elise' 'Lotus Evora' 'MINI Countryman'
#  'Lotus Exige' 'Chevrolet Sonic Sedan' 'Chevrolet Malibu Hybrid'
#  'Maserati GranTurismo Coup' 'Maserati GranTurismo Convertible'
#  'Maserati Quattroporte' 'Jeep Wrangler' 'Honda Ridgeline'
#  'MINI Cooper Coupe' 'Mercury Grand Marquis' 'Mercury Mariner'
#  'BMW M6 Convertible' 'BMW M6 Coup' 'BMW X3' 'Chevrolet Sonic Hatchback'
#  'Chevrolet Suburban Half-Ton' 'Chevrolet Suburban Three-Quarter-Ton'
#  'Chevrolet Suburban' 'Subaru Impreza Hatchback'
#  'Subaru Impreza WRX Hatchback' 'Dodge Ram 1500' 'Chevrolet Tahoe'
#  'Chevrolet Tahoe Hybrid' 'BMW Z4 Roadster' 'Chevrolet Traverse'
#  'Cadillac Escalade EXT' 'Saab 9-4X' 'Aston Martin V12 Vantage'
#  'Saab 9-5 Sedan' 'Mercury Milan' 'Aston Martin V8 Vantage Roadster'
#  'Aston Martin V8 Vantage Coup' 'Chevrolet Avalanche' 'Subaru Legacy'
#  'Lexus IS' 'Toyota Tacoma' 'Scion xB' 'Scion xD'
#  'Aston Martin Virage Volante' 'Toyota Tundra' 'Lexus IS C'
#  'Aston Martin Virage Coup' 'Suzuki Equator' 'Nissan Frontier'
#  'Subaru Outback' 'Chevrolet Silverado 1500 Hybrid' 'Ford Ranger'
#  'Lexus IS F' 'lexus IS F' 'Lexus LX' 'Ford E-150 Wagon'
#  'Ford E-350 Super Duty Wagon' 'Dodge Dakota' 'Ford E-150 Van'
#  'Nissan Titan' 'Ford E-250 Van' 'Ford E-350 Super Duty Van' 'Ford F-150'
#  'GMC Sierra 1500 Hybrid' 'BMW 1 Series Coup' 'Ford Focus 5-Door'
#  'Nissan JUKE' 'Hyundai Veloster' 'Audi TT RS' 'Lexus RX' 'Lexus LFA'
#  'Kia Rio 5-Door' 'Volkswagen Passat' 'Volkswagen Touareg Hybrid'
#  'Honda Civic Coupe' 'Volkswagen Golf R 2-Door' 'Volkswagen Golf R 4-Door'
#  'Volkswagen Beetle' 'Cadillac SRX Crossover' 'Buick Verano'
#  'Suzuki SX4 Crossover' 'Lincoln MKZ' 'Bentley Mulsanne'
#  'Lamborghini Gallardo Coup' 'Lamborghini Gallardo Spyder']
# year [2009 2012 2010 2011]
# horsepower [250 200 265 350 280 211 305 555 185 310 324 195 302 227 530 621 552 600
#  168 300 325 240 311 281 235 270 157 271 190 332 120 177 268 169 179 160
#  140 175 567 500 132 563 453 170 115 158 260 187 381 631 543 604 620 317
#  108 372 122 197 333 225 550 380 357 560 138 110 283 263 234 272 269 323
#  426 188 312 228 230 145 148 156 173 420 525 430 385 429 274 166 194 290
#  368 210 306 451 412 444 142 315 244 276 191 304 176 113 266 285 354 435
#  505 251 198 249 117 165 161 262 355 273 382 510 518 536 507 162 556 152
#  297 320 638 403 291 275 292 335 171 136 107 180 261 360 503 400 109 100
#  167 153 239 303 390 172 379 470 425 330 182 370 288 232 212 218 106 264
#  224 345 408 242 328 535 455 348 352 414 135 201 255 405 155 252 248 150
#  342 220 375 540 186 121 181 208 118 363 178 189 217 257 164 433 440 202
#  205 215 256 204 159 236 128 490 143 207 416 383 365 411 465 376 318 308]
# torque [236 207 243 325 266 258 254 273 500 190 334 295 373 260 305 276 774 590
#  479 553 170 354 278 178 251 162 270 112 161 248 167 171 146 136 180 516
#  738 128 575 531 177 125 271 310 186 401 664 385 105 265 328 127 139 406
#  398 367 344 123 106 233 263 257 226 172 246 420 221 200 300 130 131 133
#  223 249 228 144 168 317 391 316 333 291 376 269 154 169 184 107 264 324
#  443 280 390 380 115 137 240 510 253 181 109 288 388 250 470 424 230 259
#  179 163 229 350 612 465 262 255 157 551 327 332 604 147 400 417 145 215
#  425 339 148 111 166 281 360 245 450 267  98 135 315 365 287 369 272 141
#  165 268 410 336 182 395 140 159 187 103 222 175 480 235 389 242 320 205
#  550 330 232 515 335 382 393 413 142 214 560 427 150 216 174 217 213 274
#  237 244 290 234 375 461 434 191 173 114 192 160 394 155 156 158 361 247
#  275 383 225 407 220 346 185 277 238 338 371 403 286 329 294 463 343 502
#  752]
# engine_make ['Audi' 'Acura' 'BMW' 'Chevrolet' 'Nissan' 'Volvo' 'Bentley' 'Toyota'
#  'Honda' 'Ford' 'Rolls-Royce' 'Volkswagen' 'Maybach' 'Lamborghini' 'Lexus'
#  'Hyundai' 'Mercedes-Benz' 'Kia' 'Mercedes-AMG' 'Mazda' 'Cadillac'
#  'Mitsubishi' 'Infiniti' 'Dodge' 'Lincoln' 'infiniti' 'GMC' 'Porsche'
#  'Jeep' 'Subaru' 'Buick' 'Suzuki' 'Saab' 'Aston Martin' 'Land Rover'
#  'Chrysler' 'Ferrari' 'Scion' 'Mini' 'MINI' 'Jaguar' 'Lotus' 'Maserati'
#  'Mercury']
# engine_capacity ['3.2' '2.0' '4.2' '3.6' '3.5' '3.7' '4.4' '2.9' '5.3' '4.8' '6.0' '4.3'
#  '2.5' '6.8' '2.4' '3.0' '4.0' '2.7' '1.6' '1.8' '6.6' '6.7' '5.7' '5.5'
#  '5.6' '5.2' '4.6' '3.3' '3.8' '6.2' '5.0' '6.3' '5.4' '7.0' '1.5' '2.3'
#  '1.4' '3' '2.8' '6.4' '4.5' '6.1' '1.3' '3.4' '8.4' '2.2' '3.9' '5.9'
#  '5.' '4.7' '5' '2']
# engine_cylinders ['6' '4' '8' '5' '12' '10']
# engine_modifier [None 'Turbo' 'FFV' 'S-charged' 'Hybrid' 'ft-lbs' 'CNG' 'S-Charged'
#  'TURBO' 'PZEV']

# %% [markdown]
# Convert relevant dtypes

# %%
df_copy["engine_capacity"] = df_copy["engine_capacity"].astype("float64")
df_copy["engine_cylinders"] = df_copy["engine_cylinders"].astype("int64")

df_copy.dtypes
# Out:
# height                 int64
# length                 int64
# width                  int64
# driveline           category
# num_gears              int64
# city_mpg               int64
# fuel_type           category
# highway_mpg            int64
# transmission        category
# id                    object
# make                  object
# model                 object
# year                   int64
# horsepower             int64
# torque                 int64
# engine_make           object
# engine_capacity      float64
# engine_cylinders       int64
# engine_modifier       object
# dtype: object

# %% [markdown]
# Check for missing values

# %%
df_copy.isna().sum() /len(df)*100
# Out:
# height               0.000000
# length               0.000000
# width                0.000000
# driveline            0.000000
# num_gears            0.000000
# city_mpg             0.000000
# fuel_type            0.000000
# highway_mpg          0.000000
# transmission         0.000000
# id                   0.000000
# make                 0.000000
# model                0.000000
# year                 0.000000
# horsepower           0.000000
# torque               0.000000
# engine_make          0.000000
# engine_capacity      0.000000
# engine_cylinders     0.000000
# engine_modifier     68.727634
# dtype: float64

# %% [markdown]
# Fill missing values with pd.na

# %%
df_copy["engine_modifier"].fillna(pd.NA)

df_copy["engine_modifier"]
# Out:
# 0        None
# 1       Turbo
# 2       Turbo
# 3       Turbo
# 5        None
#         ...
# 5071     None
# 5072     None
# 5073     None
# 5074     None
# 5075     None
# Name: engine_modifier, Length: 5030, dtype: object

# %% [markdown]
# Export cleaned data to csv

# %%
df_copy.to_csv("cleaned_cars.csv", index=False)

# %% [markdown]
# Create copies of df for each MySQL table.

# %%
df_car = df_copy[["id", "make", "model", "year", "horsepower", "torque", "engine_make", "engine_capacity", "engine_cylinders", "engine_modifier"]].copy()
df_driveline = df_copy[["id", "driveline"]].copy()
df_transmission = df_copy[["id", "transmission"]].copy()
df_fuel_type = df_copy[["id", "fuel_type"]].copy()
df_mileage = df_copy[["id", "city_mpg", "highway_mpg"]].copy()
df_driveline.rename(columns={"id": "car_id"}, inplace=True)
df_transmission.rename(columns={"id": "car_id"}, inplace=True)
df_fuel_type.rename(columns={"id": "car_id"}, inplace=True)
df_mileage.rename(columns={"id": "car_id"}, inplace=True)

# Save each df to a csv.

df_car.to_csv("car_table.csv", index=False)
df_driveline.index += 1
df_driveline.to_csv("driveline_table.csv", index_label="Index")
df_transmission.index += 1
df_transmission.to_csv("transmission_table.csv", index_label="Index")
df_fuel_type.index += 1
df_fuel_type.to_csv("fuel_type_table.csv", index_label="Index")
df_mileage.index += 1
df_mileage.to_csv("mileage_table.csv", index_label="Index")
